# %% [markdown]
# ## Question 3

# %%
"""
Instruction:

In this section, you are asked to train a NN with different hyperparameters.
To start with training, you need to fill in the incomplete code. There are 3
places that you need to complete:
a) Backward pass equations for an affine layer (linear transformation + bias).
b) Backward pass equations for ReLU activation function.
c) Weight update equations with momentum.

After correctly fill in the code, modify the hyperparameters in "main()".
You can then run this file with the command: "python nn.py" in your terminal.
The program will automatically check your gradient implementation before start.
The program will print out the training progress, and it will display the
training curve by the end. You can optionally save the model by uncommenting
the lines in "main()".
"""

from __future__ import division
from __future__ import print_function

from util import LoadData, Load, Save, DisplayPlot
import sys
import numpy as np

# %%
def InitNN(num_inputs, num_hiddens, num_outputs):
    """Initializes NN parameters.

    Args:
        num_inputs:    Number of input units.
        num_hiddens:   List of two elements, hidden size for each layer.
        num_outputs:   Number of output units.

    Returns:
        model:         Randomly initialized network weights.
    """
    W1 = 0.1 * np.random.randn(num_inputs, num_hiddens[0])
    W2 = 0.1 * np.random.randn(num_hiddens[0], num_hiddens[1])
    W3 = 0.01 * np.random.randn(num_hiddens[1], num_outputs)
    b1 = np.zeros((num_hiddens[0]))
    b2 = np.zeros((num_hiddens[1]))
    b3 = np.zeros((num_outputs))
    model = {
        'V_w1': np.zeros((num_inputs, num_hiddens[0])),
        'V_w2': np.zeros(num_hiddens),
        'V_w3': np.zeros((num_hiddens[1], num_outputs)),
        'W1': W1,
        'W2': W2,
        'W3': W3,
        'b1': b1,
        'b2': b2,
        'b3': b3
    }
    return model

# %%
def Affine(x, w, b):
    """Computes the affine transformation.

    Args:
        x: Inputs (or hidden layers)
        w: Weights
        b: Bias

    Returns:
        y: Outputs
    """
    # y = np.dot(w.T, x) + b
    y = x.dot(w) + b
    return y

# %%
def AffineBackward(grad_y, h, w):
    """Computes gradients of affine transformation.
    hint: you may need the matrix transpose np.dot(A,B).T = np.dot(B,A) and (A.T).T = A

    Args:
        grad_y: gradient from last layer
        h: inputs from the hidden layer
        w: weights from last layer

    Returns:
        grad_h: Gradients wrt. the inputs/hidden layer.
        grad_w: Gradients wrt. the weights.
        grad_b: Gradients wrt. the biases.
    """
    # Insert your code here.
    grad_h = np.dot(grad_y, w.T)
    grad_w = np.dot(h.T, grad_y)
    grad_b = np.sum(grad_y, axis=0)
    return grad_h, grad_w, grad_b

# %%
def ReLU(z):
    """Computes the ReLU activation function.

    Args:
        z: Inputs

    Returns:
        h: Activation of z
    """
    return np.maximum(z, 0.0)

# %%
def ReLUBackward(grad_h, z):
    """Computes gradients of the ReLU activation function wrt. the unactivated inputs.

    Args:
        z: Inputs

    Returns:
        grad_z: Gradients wrt. the hidden state prior to activation.
    """
    grad_z = grad_h * (z > 0)
    return grad_z

# %%
def Softmax(x):
    """Computes the softmax activation function.

    Args:
        x: Inputs

    Returns:
        y: Activation
    """
    return np.exp(x) / np.exp(x).sum(axis=1, keepdims=True)

# %%
def NNForward(model, x):
    """Runs the forward pass.
var = {
    Args:
        model: Dictionary of all the weights.
        x:     Input to the network.

    Returns:
        var:   Dictionary of all intermediate variables.
    """
    z1 = Affine(x, model['W1'], model['b1'])
    h1 = ReLU(z1)
    z2 = Affine(h1, model['W2'], model['b2'])
    h2 = ReLU(z2)
    y = Affine(h2, model['W3'], model['b3'])
    var = {
        'x': x,
        'z1': z1,
        'h1': h1,
        'z2': z2,
        'h2': h2,
        'y': y
    }
    return var

# %%
def NNBackward(model, err, var):
    """Runs the backward pass.

    Args:
        model:    Dictionary of all the weights.
        err:      Gradients to the output of the network.
        var:      Intermediate variables from the forward pass.
    """
    dE_dh2, dE_dW3, dE_db3 = AffineBackward(err, var['h2'], model['W3'])
    dE_dz2 = ReLUBackward(dE_dh2, var['z2'])
    dE_dh1, dE_dW2, dE_db2 = AffineBackward(dE_dz2, var['h1'], model['W2'])
    dE_dz1 = ReLUBackward(dE_dh1, var['z1'])
    _, dE_dW1, dE_db1 = AffineBackward(dE_dz1, var['x'], model['W1'])
    model['dE_dW1'] = dE_dW1
    model['dE_dW2'] = dE_dW2
    model['dE_dW3'] = dE_dW3
    model['dE_db1'] = dE_db1
    model['dE_db2'] = dE_db2
    model['dE_db3'] = dE_db3
    pass

# %%
def NNUpdate(model, eps, momentum):
    """Update NN weights.

    Args:
        model:    Dictionary of all the weights.
        eps:      Learning rate.
        momentum: Momentum.
    """
    # Insert your code here.
    # Update velocities
    model['V_w1'] = momentum * model['V_w1'] + (1 - momentum) * model['dE_dW1']
    model['V_w2'] = momentum * model['V_w2'] + (1 - momentum) * model['dE_dW2']
    model['V_w3'] = momentum * model['V_w3'] + (1 - momentum) * model['dE_dW3']
    # Update the weights and biases.
    model['W1'] -= eps * model['V_w1']
    model['W2'] -= eps * model['V_w2']
    model['W3'] -= eps * model['V_w3']
    model['b1'] -= eps * model['dE_db1']
    model['b2'] -= eps * model['dE_db2']
    model['b3'] -= eps * model['dE_db3']

# %%
def Train(model, forward, backward, update, hypers, verbose=True, diagram=True):
    # %matplotlib tk
    """Trains a simple MLP.

    Args:
        model:           Dictionary of model weights.
        forward:         Forward prop function.
        backward:        Backward prop function.
        update:          Update weights function.
        eps:             Learning rate.
        momentum:        Momentum.
        num_epochs:      Number of epochs to run training for.
        batch_size:      Mini-batch size, -1 for full batch.

    Returns:
        stats:           Dictionary of training statistics.
            - train_ce:       Training cross entropy.
            - valid_ce:       Validation cross entropy.
            - train_acc:      Training accuracy.
            - valid_acc:      Validation accuracy.
    """
    eps, momentum, num_epochs, batch_size = \
        hypers["eps"], hypers["momentum"], hypers["num_epochs"], hypers["batch_size"]
    inputs_train, inputs_valid, inputs_test, target_train, target_valid, \
        target_test = LoadData('./toronto_face.npz')
    rnd_idx = np.arange(inputs_train.shape[0])
    train_ce_list = []
    valid_ce_list = []
    train_acc_list = []
    valid_acc_list = []
    num_train_cases = inputs_train.shape[0]
    if batch_size == -1:
        batch_size = num_train_cases
    num_steps = int(np.ceil(num_train_cases / batch_size))
    for epoch in range(num_epochs):
        np.random.shuffle(rnd_idx)
        inputs_train = inputs_train[rnd_idx]
        target_train = target_train[rnd_idx]
        for step in range(num_steps):
            # Forward prop.
            start = step * batch_size
            end = min(num_train_cases, (step + 1) * batch_size)
            x = inputs_train[start: end]
            t = target_train[start: end]

            var = forward(model, x)
            prediction = Softmax(var['y'])

            train_ce = -np.sum(t * np.log(prediction)) / x.shape[0]
            train_acc = (np.argmax(prediction, axis=1) ==
                         np.argmax(t, axis=1)).astype('float').mean()
            if verbose:
                print(('Epoch {:3d} Step {:2d} Train CE {:.5f} '
                       'Train Acc {:.5f}').format(
                    epoch, step, train_ce, train_acc))

            # Compute error.
            error = (prediction - t) / x.shape[0]

            # Backward prop.
            backward(model, error, var)

            # Update weights.
            update(model, eps, momentum)

        valid_ce, valid_acc = Evaluate(
            inputs_valid, target_valid, model, forward, batch_size=batch_size)
        if verbose:
            print(('Epoch {:3d} '
                   'Validation CE {:.5f} '
                   'Validation Acc {:.5f}\n').format(
                epoch, valid_ce, valid_acc))
        train_ce_list.append((epoch, train_ce))
        train_acc_list.append((epoch, train_acc))
        valid_ce_list.append((epoch, valid_ce))
        valid_acc_list.append((epoch, valid_acc))
        if diagram:
            DisplayPlot(train_ce_list, valid_ce_list, 'Cross Entropy', number=0)
            DisplayPlot(train_acc_list, valid_acc_list, 'Accuracy', number=1)

    if verbose:
        print()
    train_ce, train_acc = Evaluate(
        inputs_train, target_train, model, forward, batch_size=batch_size)
    valid_ce, valid_acc = Evaluate(
        inputs_valid, target_valid, model, forward, batch_size=batch_size)
    test_ce, test_acc = Evaluate(
        inputs_test, target_test, model, forward, batch_size=batch_size)
    print('CE: Train %.5f Validation %.5f Test %.5f' %
          (train_ce, valid_ce, test_ce))
    print('Acc: Train {:.5f} Validation {:.5f} Test {:.5f}'.format(
        train_acc, valid_acc, test_acc))

    stats = {
        'train_ce': train_ce_list,
        'valid_ce': valid_ce_list,
        'train_acc': train_acc_list,
        'valid_acc': valid_acc_list
    }

    return model, stats

# %%
def Evaluate(inputs, target, model, forward, batch_size=-1):
    """Evaluates the model on inputs and target.

    Args:
        inputs: Inputs to the network.
        target: Target of the inputs.
        model:  Dictionary of network weights.
    """
    num_cases = inputs.shape[0]
    if batch_size == -1:
        batch_size = num_cases
    num_steps = int(np.ceil(num_cases / batch_size))
    ce = 0.0
    acc = 0.0
    for step in range(num_steps):
        start = step * batch_size
        end = min(num_cases, (step + 1) * batch_size)
        x = inputs[start: end]
        t = target[start: end]
        prediction = Softmax(forward(model, x)['y'])
        ce += -np.sum(t * np.log(prediction))
        acc += (np.argmax(prediction, axis=1) == np.argmax(
            t, axis=1)).astype('float').sum()
    ce /= num_cases
    acc /= num_cases
    return ce, acc

# %%
def CheckGrad(model, forward, backward, name, x):
    """Check the gradients

    Args:
        model: Dictionary of network weights.
        name: Weights name to check.
        x: Fake input.
    """
    np.random.seed(0)
    var = forward(model, x)
    loss = lambda y: 0.5 * (y ** 2).sum()
    grad_y = var['y']
    backward(model, grad_y, var)
    grad_w = model['dE_d' + name].ravel()
    w_ = model[name].ravel()
    eps = 1e-7
    grad_w_2 = np.zeros(w_.shape)
    check_elem = np.arange(w_.size)
    np.random.shuffle(check_elem)
    # Randomly check 20 elements.
    check_elem = check_elem[:20]
    for ii in check_elem:
        w_[ii] += eps
        err_plus = loss(forward(model, x)['y'])
        w_[ii] -= 2 * eps
        err_minus = loss(forward(model, x)['y'])
        w_[ii] += eps
        grad_w_2[ii] = (err_plus - err_minus) / 2 / eps
    np.testing.assert_almost_equal(grad_w[check_elem], grad_w_2[check_elem],
                                   decimal=3)

# %%
def CheckGrad(model, forward, backward, name, x):
    """Check the gradients

    Args:
        model: Dictionary of network weights.
        name: Weights name to check.
        x: Fake input.
    """
    np.random.seed(0)
    var = forward(model, x)
    loss = lambda y: 0.5 * (y ** 2).sum()
    grad_y = var['y']
    backward(model, grad_y, var)
    grad_w = model['dE_d' + name].ravel()
    w_ = model[name].ravel()
    eps = 1e-7
    grad_w_2 = np.zeros(w_.shape)
    check_elem = np.arange(w_.size)
    np.random.shuffle(check_elem)
    # Randomly check 20 elements.
    check_elem = check_elem[:20]
    for ii in check_elem:
        w_[ii] += eps
        err_plus = loss(forward(model, x)['y'])
        w_[ii] -= 2 * eps
        err_minus = loss(forward(model, x)['y'])
        w_[ii] += eps
        grad_w_2[ii] = (err_plus - err_minus) / 2 / eps
    np.testing.assert_almost_equal(grad_w[check_elem], grad_w_2[check_elem],
                                   decimal=3)

# %%
# Export name
model_fname = 'nn_model.npz'
stats_fname = 'nn_stats.npz'

# %%
# Setup hyperparameters
hyperparameters = {
    "num_hiddens": [16, 32],
    "eps": 0.1,
    "momentum": 0.0,
    "num_epochs": 1000,
    "batch_size": 100
}

# %%
# Input-output dimensions.
num_inputs = 2304
num_outputs = 7

# Initialize model.
model = InitNN(num_inputs, hyperparameters["num_hiddens"], num_outputs)

# Uncomment to reload trained model here.
# model = Load(model_fname)

# Check gradient implementation.
print('Checking gradients...')
x = np.random.rand(10, 48 * 48) * 0.1
CheckGrad(model, NNForward, NNBackward, 'W3', x)
CheckGrad(model, NNForward, NNBackward, 'b3', x)
CheckGrad(model, NNForward, NNBackward, 'W2', x)
CheckGrad(model, NNForward, NNBackward, 'b2', x)
CheckGrad(model, NNForward, NNBackward, 'W1', x)
CheckGrad(model, NNForward, NNBackward, 'b1', x)
# Out:
# Checking gradients...

# %% [markdown]
# ## Q 3.1

# %% [markdown]
# #### Train with default parameters

# %%
#Train model.
stats = Train(model, NNForward, NNBackward, NNUpdate, hyperparameters, verbose=True)

# Uncomment if you wish to save the training statistics.
# Save(stats_fname, stats)
# Out:
# 0.5
# Epoch   0 Step  0 Train CE 1.94333 Train Acc 0.15000
# Epoch   0 Step  1 Train CE 1.92950 Train Acc 0.26000
# Epoch   0 Step  2 Train CE 1.91187 Train Acc 0.24000
# Epoch   0 Step  3 Train CE 1.89163 Train Acc 0.27000
# Epoch   0 Step  4 Train CE 1.87055 Train Acc 0.29000
# Epoch   0 Step  5 Train CE 1.89787 Train Acc 0.22000
# Epoch   0 Step  6 Train CE 1.88895 Train Acc 0.26000
# Epoch   0 Step  7 Train CE 1.91133 Train Acc 0.25000
# Epoch   0 Step  8 Train CE 1.89229 Train Acc 0.24000
# Epoch   0 Step  9 Train CE 1.76504 Train Acc 0.40000
# Epoch   0 Step 10 Train CE 1.77183 Train Acc 0.35000
# Epoch   0 Step 11 Train CE 1.90687 Train Acc 0.20000
# Epoch   0 Step 12 Train CE 1.88723 Train Acc 0.28000
# Epoch   0 Step 13 Train CE 1.74703 Train Acc 0.38000
# Epoch   0 Step 14 Train CE 1.89727 Train Acc 0.27000
# Epoch   0 Step 15 Train CE 1.86479 Train Acc 0.28000
# Epoch   0 Step 16 Train CE 1.83247 Train Acc 0.26000
# Epoch   0 Step 17 Train CE 1.81645 Train Acc 0.29000
# Epoch   0 Step 18 Train CE 1.92900 Train Acc 0.26000
# Epoch   0 Step 19 Train CE 1.81566 Train Acc 0.32000
# Epoch   0 Step 20 Train CE 1.86091 Train Acc 0.29000
# Epoch   0 Step 21 Train CE 1.75203 Train Acc 0.39000
# Epoch   0 Step 22 Train CE 1.89782 Train Acc 0.27000
# Epoch   0 Step 23 Train CE 1.85524 Train Acc 0.25000
# Epoch   0 Step 24 Train CE 1.83436 Train Acc 0.24000
# Epoch   0 Step 25 Train CE 1.82278 Train Acc 0.32000
# Epoch   0 Step 26 Train CE 1.80424 Train Acc 0.30000
# Epoch   0 Step 27 Train CE 1.84751 Train Acc 0.31000
# Epoch   0 Step 28 Train CE 1.81587 Train Acc 0.34000
# Epoch   0 Step 29 Train CE 1.79834 Train Acc 0.31000
# Epoch   0 Step 30 Train CE 1.91602 Train Acc 0.21000
# Epoch   0 Step 31 Train CE 1.79494 Train Acc 0.32000
# Epoch   0 Step 32 Train CE 1.80715 Train Acc 0.29000
# Epoch   0 Step 33 Train CE 1.83941 Train Acc 0.28378
# Epoch   0 Validation CE 1.83613 Validation Acc 0.27924
#
# Epoch   1 Step  0 Train CE 1.85387 Train Acc 0.24000
# Epoch   1 Step  1 Train CE 1.82258 Train Acc 0.35000
# Epoch   1 Step  2 Train CE 1.88937 Train Acc 0.22000
# Epoch   1 Step  3 Train CE 1.81228 Train Acc 0.32000
# Epoch   1 Step  4 Train CE 1.76072 Train Acc 0.36000
# Epoch   1 Step  5 Train CE 1.86246 Train Acc 0.25000
# Epoch   1 Step  6 Train CE 1.87763 Train Acc 0.26000
# Epoch   1 Step  7 Train CE 1.83923 Train Acc 0.25000
# Epoch   1 Step  8 Train CE 1.86770 Train Acc 0.27000
# Epoch   1 Step  9 Train CE 1.79728 Train Acc 0.30000
# Epoch   1 Step 10 Train CE 1.77441 Train Acc 0.31000
# Epoch   1 Step 11 Train CE 1.84862 Train Acc 0.29000
# Epoch   1 Step 12 Train CE 1.83304 Train Acc 0.29000
# Epoch   1 Step 13 Train CE 1.83127 Train Acc 0.29000
# Epoch   1 Step 14 Train CE 1.75940 Train Acc 0.38000
# Epoch   1 Step 15 Train CE 1.82733 Train Acc 0.25000
# Epoch   1 Step 16 Train CE 1.84316 Train Acc 0.26000
# Epoch   1 Step 17 Train CE 1.74508 Train Acc 0.37000
# Epoch   1 Step 18 Train CE 1.86742 Train Acc 0.27000
# Epoch   1 Step 19 Train CE 1.84811 Train Acc 0.31000
# Epoch   1 Step 20 Train CE 1.75406 Train Acc 0.33000
# Epoch   1 Step 21 Train CE 1.88841 Train Acc 0.26000
# Epoch   1 Step 22 Train CE 1.78092 Train Acc 0.33000
# Epoch   1 Step 23 Train CE 1.78611 Train Acc 0.29000
# Epoch   1 Step 24 Train CE 1.80604 Train Acc 0.28000
# Epoch   1 Step 25 Train CE 1.80930 Train Acc 0.26000
# Epoch   1 Step 26 Train CE 1.78259 Train Acc 0.36000
# Epoch   1 Step 27 Train CE 1.86742 Train Acc 0.27000
# Epoch   1 Step 28 Train CE 1.84088 Train Acc 0.21000
# Epoch   1 Step 29 Train CE 1.84114 Train Acc 0.35000
# Epoch   1 Step 30 Train CE 1.78908 Train Acc 0.34000
# Epoch   1 Step 31 Train CE 1.81833 Train Acc 0.29000
# Epoch   1 Step 32 Train CE 1.82306 Train Acc 0.26000
# Epoch   1 Step 33 Train CE 1.81236 Train Acc 0.24324
# Epoch   1 Validation CE 1.79489 Validation Acc 0.37709
#
# Epoch   2 Step  0 Train CE 1.77653 Train Acc 0.41000
# Epoch   2 Step  1 Train CE 1.75171 Train Acc 0.32000
# Epoch   2 Step  2 Train CE 1.77469 Train Acc 0.29000
# Epoch   2 Step  3 Train CE 1.79612 Train Acc 0.28000
# Epoch   2 Step  4 Train CE 1.70952 Train Acc 0.47000
# Epoch   2 Step  5 Train CE 1.80404 Train Acc 0.30000
# Epoch   2 Step  6 Train CE 1.78057 Train Acc 0.37000
# Epoch   2 Step  7 Train CE 1.78230 Train Acc 0.31000
# Epoch   2 Step  8 Train CE 1.73255 Train Acc 0.42000
# Epoch   2 Step  9 Train CE 1.87647 Train Acc 0.26000
# Epoch   2 Step 10 Train CE 1.82861 Train Acc 0.31000
# Epoch   2 Step 11 Train CE 1.72542 Train Acc 0.27000
# Epoch   2 Step 12 Train CE 1.86175 Train Acc 0.23000
# Epoch   2 Step 13 Train CE 1.80817 Train Acc 0.26000
# Epoch   2 Step 14 Train CE 1.79398 Train Acc 0.35000
# Epoch   2 Step 15 Train CE 1.69963 Train Acc 0.38000
# Epoch   2 Step 16 Train CE 1.86633 Train Acc 0.23000
# Epoch   2 Step 17 Train CE 1.76613 Train Acc 0.44000
# Epoch   2 Step 18 Train CE 1.76913 Train Acc 0.31000
# Epoch   2 Step 19 Train CE 1.77493 Train Acc 0.35000
# Epoch   2 Step 20 Train CE 1.71689 Train Acc 0.33000
# Epoch   2 Step 21 Train CE 1.81683 Train Acc 0.26000
# Epoch   2 Step 22 Train CE 1.82945 Train Acc 0.23000
# Epoch   2 Step 23 Train CE 1.81383 Train Acc 0.32000
# Epoch   2 Step 24 Train CE 1.78163 Train Acc 0.29000
# Epoch   2 Step 25 Train CE 1.67440 Train Acc 0.41000
# Epoch   2 Step 26 Train CE 1.70069 Train Acc 0.37000
# Epoch   2 Step 27 Train CE 1.72712 Train Acc 0.35000
# Epoch   2 Step 28 Train CE 1.74764 Train Acc 0.28000
# Epoch   2 Step 29 Train CE 1.96900 Train Acc 0.29000
# Epoch   2 Step 30 Train CE 1.81058 Train Acc 0.26000
# Epoch   2 Step 31 Train CE 1.81737 Train Acc 0.29000
# Epoch   2 Step 32 Train CE 1.76065 Train Acc 0.37000
# Epoch   2 Step 33 Train CE 1.74370 Train Acc 0.32432
# Epoch   2 Validation CE 1.71850 Validation Acc 0.35800
#
# Epoch   3 Step  0 Train CE 1.71497 Train Acc 0.36000
# Epoch   3 Step  1 Train CE 1.72848 Train Acc 0.38000
# Epoch   3 Step  2 Train CE 1.80235 Train Acc 0.24000
# Epoch   3 Step  3 Train CE 1.85549 Train Acc 0.20000
# Epoch   3 Step  4 Train CE 1.89601 Train Acc 0.29000
# Epoch   3 Step  5 Train CE 1.75085 Train Acc 0.30000
# Epoch   3 Step  6 Train CE 1.76293 Train Acc 0.30000
# Epoch   3 Step  7 Train CE 1.77223 Train Acc 0.31000
# Epoch   3 Step  8 Train CE 1.75284 Train Acc 0.30000
# Epoch   3 Step  9 Train CE 1.69140 Train Acc 0.34000
# Epoch   3 Step 10 Train CE 1.71920 Train Acc 0.37000
# Epoch   3 Step 11 Train CE 1.71231 Train Acc 0.32000
# Epoch   3 Step 12 Train CE 1.66862 Train Acc 0.39000
# Epoch   3 Step 13 Train CE 1.67172 Train Acc 0.30000
# Epoch   3 Step 14 Train CE 1.71616 Train Acc 0.26000
# Epoch   3 Step 15 Train CE 2.22652 Train Acc 0.21000
# Epoch   3 Step 16 Train CE 1.87442 Train Acc 0.37000
# Epoch   3 Step 17 Train CE 1.79117 Train Acc 0.42000
# Epoch   3 Step 18 Train CE 1.73021 Train Acc 0.34000
# Epoch   3 Step 19 Train CE 1.72935 Train Acc 0.36000
# Epoch   3 Step 20 Train CE 1.73865 Train Acc 0.37000
# Epoch   3 Step 21 Train CE 1.74704 Train Acc 0.39000
# Epoch   3 Step 22 Train CE 1.76808 Train Acc 0.32000
# Epoch   3 Step 23 Train CE 1.69623 Train Acc 0.35000
# Epoch   3 Step 24 Train CE 1.93667 Train Acc 0.22000
# Epoch   3 Step 25 Train CE 1.92143 Train Acc 0.30000
# Epoch   3 Step 26 Train CE 1.84530 Train Acc 0.29000
# Epoch   3 Step 27 Train CE 1.79282 Train Acc 0.23000
# Epoch   3 Step 28 Train CE 1.76635 Train Acc 0.32000
# Epoch   3 Step 29 Train CE 1.74887 Train Acc 0.35000
# Epoch   3 Step 30 Train CE 1.76712 Train Acc 0.35000
# Epoch   3 Step 31 Train CE 1.74697 Train Acc 0.29000
# Epoch   3 Step 32 Train CE 1.58753 Train Acc 0.42000
# Epoch   3 Step 33 Train CE 1.78265 Train Acc 0.35135
# Epoch   3 Validation CE 1.81460 Validation Acc 0.32220
#
# Epoch   4 Step  0 Train CE 1.78045 Train Acc 0.37000
# Epoch   4 Step  1 Train CE 1.68422 Train Acc 0.41000
# Epoch   4 Step  2 Train CE 1.69302 Train Acc 0.37000
# Epoch   4 Step  3 Train CE 1.60666 Train Acc 0.33000
# Epoch   4 Step  4 Train CE 2.34271 Train Acc 0.24000
# Epoch   4 Step  5 Train CE 1.89692 Train Acc 0.25000
# Epoch   4 Step  6 Train CE 1.80096 Train Acc 0.34000
# Epoch   4 Step  7 Train CE 1.84438 Train Acc 0.31000
# Epoch   4 Step  8 Train CE 1.75297 Train Acc 0.52000
# Epoch   4 Step  9 Train CE 1.77057 Train Acc 0.36000
# Epoch   4 Step 10 Train CE 1.70796 Train Acc 0.40000
# Epoch   4 Step 11 Train CE 1.70662 Train Acc 0.41000
# Epoch   4 Step 12 Train CE 1.78276 Train Acc 0.23000
# Epoch   4 Step 13 Train CE 1.61464 Train Acc 0.41000
# Epoch   4 Step 14 Train CE 1.70005 Train Acc 0.36000
# Epoch   4 Step 15 Train CE 1.69460 Train Acc 0.36000
# Epoch   4 Step 16 Train CE 1.95254 Train Acc 0.28000
# Epoch   4 Step 17 Train CE 1.95520 Train Acc 0.25000
# Epoch   4 Step 18 Train CE 1.96525 Train Acc 0.19000
# Epoch   4 Step 19 Train CE 1.72297 Train Acc 0.36000
# Epoch   4 Step 20 Train CE 1.67416 Train Acc 0.34000
# Epoch   4 Step 21 Train CE 1.63466 Train Acc 0.41000
# Epoch   4 Step 22 Train CE 1.65090 Train Acc 0.41000
# Epoch   4 Step 23 Train CE 1.60921 Train Acc 0.38000
# Epoch   4 Step 24 Train CE 1.87744 Train Acc 0.22000
# Epoch   4 Step 25 Train CE 2.05394 Train Acc 0.26000
# Epoch   4 Step 26 Train CE 1.82193 Train Acc 0.32000
# Epoch   4 Step 27 Train CE 1.82198 Train Acc 0.22000
# Epoch   4 Step 28 Train CE 1.81400 Train Acc 0.34000
# Epoch   4 Step 29 Train CE 1.70306 Train Acc 0.35000
# Epoch   4 Step 30 Train CE 1.59796 Train Acc 0.48000
# Epoch   4 Step 31 Train CE 1.60139 Train Acc 0.38000
# Epoch   4 Step 32 Train CE 1.68450 Train Acc 0.26000
# Epoch   4 Step 33 Train CE 1.68414 Train Acc 0.48649
# Epoch   4 Validation CE 1.65024 Validation Acc 0.33413
# Epoch   5 Step  0 Train CE 1.65662 Train Acc 0.35000
# Epoch   5 Step  1 Train CE 1.66598 Train Acc 0.45000
# Epoch   5 Step  2 Train CE 1.74631 Train Acc 0.31000
# Epoch   5 Step  3 Train CE 1.74031 Train Acc 0.37000
# Epoch   5 Step  4 Train CE 2.02862 Train Acc 0.23000
# Epoch   5 Step  5 Train CE 2.53069 Train Acc 0.05000
# Epoch   5 Step  6 Train CE 1.83299 Train Acc 0.29000
# Epoch   5 Step  7 Train CE 1.88206 Train Acc 0.23000
# Epoch   5 Step  8 Train CE 1.84850 Train Acc 0.24000
# Epoch   5 Step  9 Train CE 1.79338 Train Acc 0.28000
# Epoch   5 Step 10 Train CE 1.75645 Train Acc 0.30000
# Epoch   5 Step 11 Train CE 1.72936 Train Acc 0.32000
# Epoch   5 Step 12 Train CE 1.71293 Train Acc 0.33000
# Epoch   5 Step 13 Train CE 1.76619 Train Acc 0.46000
# Epoch   5 Step 14 Train CE 1.77989 Train Acc 0.30000
# Epoch   5 Step 15 Train CE 1.71009 Train Acc 0.39000
# Epoch   5 Step 16 Train CE 1.70452 Train Acc 0.39000
# Epoch   5 Step 17 Train CE 1.74531 Train Acc 0.28000
# Epoch   5 Step 18 Train CE 1.80153 Train Acc 0.30000
# Epoch   5 Step 19 Train CE 1.76777 Train Acc 0.24000
# Epoch   5 Step 20 Train CE 1.66665 Train Acc 0.35000
# Epoch   5 Step 21 Train CE 1.60299 Train Acc 0.38000
# Epoch   5 Step 22 Train CE 1.68089 Train Acc 0.38000
# Epoch   5 Step 23 Train CE 1.61081 Train Acc 0.39000
# Epoch   5 Step 24 Train CE 1.73398 Train Acc 0.31000
# Epoch   5 Step 25 Train CE 1.94402 Train Acc 0.20000
# Epoch   5 Step 26 Train CE 1.78608 Train Acc 0.36000
# Epoch   5 Step 27 Train CE 1.75490 Train Acc 0.26000
# Epoch   5 Step 28 Train CE 1.60535 Train Acc 0.44000
# Epoch   5 Step 29 Train CE 1.51467 Train Acc 0.42000
# Epoch   5 Step 30 Train CE 1.70447 Train Acc 0.33000
# Epoch   5 Step 31 Train CE 1.82680 Train Acc 0.26000
# Epoch   5 Step 32 Train CE 1.87707 Train Acc 0.19000
# Epoch   5 Step 33 Train CE 1.76361 Train Acc 0.35135
# Epoch   5 Validation CE 1.60754 Validation Acc 0.41289
#
# Epoch   6 Step  0 Train CE 1.68123 Train Acc 0.35000
# Epoch   6 Step  1 Train CE 1.70285 Train Acc 0.31000
# Epoch   6 Step  2 Train CE 1.65129 Train Acc 0.40000
# Epoch   6 Step  3 Train CE 1.64865 Train Acc 0.36000
# Epoch   6 Step  4 Train CE 1.63578 Train Acc 0.41000
# Epoch   6 Step  5 Train CE 1.58209 Train Acc 0.41000
# Epoch   6 Step  6 Train CE 1.60431 Train Acc 0.41000
# Epoch   6 Step  7 Train CE 1.62663 Train Acc 0.36000
# Epoch   6 Step  8 Train CE 2.11918 Train Acc 0.20000
# Epoch   6 Step  9 Train CE 1.94999 Train Acc 0.32000
# Epoch   6 Step 10 Train CE 1.77450 Train Acc 0.34000
# Epoch   6 Step 11 Train CE 1.71673 Train Acc 0.34000
# Epoch   6 Step 12 Train CE 1.72434 Train Acc 0.33000
# Epoch   6 Step 13 Train CE 1.68726 Train Acc 0.34000
# Epoch   6 Step 14 Train CE 1.74021 Train Acc 0.28000
# Epoch   6 Step 15 Train CE 1.76826 Train Acc 0.27000
# Epoch   6 Step 16 Train CE 1.70288 Train Acc 0.32000
# Epoch   6 Step 17 Train CE 1.72244 Train Acc 0.33000
# Epoch   6 Step 18 Train CE 1.66264 Train Acc 0.47000
# Epoch   6 Step 19 Train CE 1.76131 Train Acc 0.33000
# Epoch   6 Step 20 Train CE 1.80927 Train Acc 0.33000
# Epoch   6 Step 21 Train CE 1.67144 Train Acc 0.43000
# Epoch   6 Step 22 Train CE 1.65292 Train Acc 0.38000
# Epoch   6 Step 23 Train CE 1.73690 Train Acc 0.39000
# Epoch   6 Step 24 Train CE 1.71794 Train Acc 0.39000
# Epoch   6 Step 25 Train CE 1.75101 Train Acc 0.38000
# Epoch   6 Step 26 Train CE 1.69691 Train Acc 0.34000
# Epoch   6 Step 27 Train CE 1.76743 Train Acc 0.36000
# Epoch   6 Step 28 Train CE 1.79842 Train Acc 0.28000
# Epoch   6 Step 29 Train CE 1.94306 Train Acc 0.24000
# Epoch   6 Step 30 Train CE 1.72310 Train Acc 0.41000
# Epoch   6 Step 31 Train CE 1.62413 Train Acc 0.41000
# Epoch   6 Step 32 Train CE 1.59482 Train Acc 0.43000
# Epoch   6 Step 33 Train CE 1.65846 Train Acc 0.37838
# Epoch   6 Validation CE 1.60085 Validation Acc 0.49403
#
# Epoch   7 Step  0 Train CE 1.64226 Train Acc 0.47000
# Epoch   7 Step  1 Train CE 1.70543 Train Acc 0.34000
# Epoch   7 Step  2 Train CE 1.67435 Train Acc 0.32000
# Epoch   7 Step  3 Train CE 1.96320 Train Acc 0.30000
# Epoch   7 Step  4 Train CE 1.92522 Train Acc 0.13000
# Epoch   7 Step  5 Train CE 1.89050 Train Acc 0.16000
# Epoch   7 Step  6 Train CE 1.71714 Train Acc 0.37000
# Epoch   7 Step  7 Train CE 1.62305 Train Acc 0.37000
# Epoch   7 Step  8 Train CE 1.50492 Train Acc 0.56000
# Epoch   7 Step  9 Train CE 1.58135 Train Acc 0.35000
# Epoch   7 Step 10 Train CE 1.82691 Train Acc 0.22000
# Epoch   7 Step 11 Train CE 1.72816 Train Acc 0.33000
# Epoch   7 Step 12 Train CE 1.71278 Train Acc 0.28000
# Epoch   7 Step 13 Train CE 1.87064 Train Acc 0.32000
# Epoch   7 Step 14 Train CE 1.58942 Train Acc 0.43000
# Epoch   7 Step 15 Train CE 1.63136 Train Acc 0.46000
# Epoch   7 Step 16 Train CE 1.57154 Train Acc 0.34000
# Epoch   7 Step 17 Train CE 1.66506 Train Acc 0.34000
# Epoch   7 Step 18 Train CE 1.77041 Train Acc 0.34000
# Epoch   7 Step 19 Train CE 1.79056 Train Acc 0.39000
# Epoch   7 Step 20 Train CE 1.74422 Train Acc 0.32000
# Epoch   7 Step 21 Train CE 1.59910 Train Acc 0.48000
# Epoch   7 Step 22 Train CE 1.47091 Train Acc 0.50000
# Epoch   7 Step 23 Train CE 1.47591 Train Acc 0.47000
# Epoch   7 Step 24 Train CE 1.54165 Train Acc 0.45000
# Epoch   7 Step 25 Train CE 1.49476 Train Acc 0.56000
# Epoch   7 Step 26 Train CE 1.80745 Train Acc 0.32000
# Epoch   7 Step 27 Train CE 1.72488 Train Acc 0.36000
# Epoch   7 Step 28 Train CE 1.75802 Train Acc 0.28000
# Epoch   7 Step 29 Train CE 1.76081 Train Acc 0.28000
# Epoch   7 Step 30 Train CE 2.03565 Train Acc 0.23000
# Epoch   7 Step 31 Train CE 2.04882 Train Acc 0.12000
# Epoch   7 Step 32 Train CE 1.77835 Train Acc 0.36000
# Epoch   7 Step 33 Train CE 1.66385 Train Acc 0.47297
# Epoch   7 Validation CE 1.60846 Validation Acc 0.45107
#
# Epoch   8 Step  0 Train CE 1.57316 Train Acc 0.43000
# Epoch   8 Step  1 Train CE 1.58127 Train Acc 0.42000
# Epoch   8 Step  2 Train CE 1.71169 Train Acc 0.31000
# Epoch   8 Step  3 Train CE 2.07192 Train Acc 0.18000
# Epoch   8 Step  4 Train CE 1.82906 Train Acc 0.23000
# Epoch   8 Step  5 Train CE 1.68535 Train Acc 0.41000
# Epoch   8 Step  6 Train CE 1.67880 Train Acc 0.39000
# Epoch   8 Step  7 Train CE 1.71332 Train Acc 0.29000
# Epoch   8 Step  8 Train CE 1.84199 Train Acc 0.17000
# Epoch   8 Step  9 Train CE 1.76424 Train Acc 0.27000
# Epoch   8 Step 10 Train CE 1.70350 Train Acc 0.35000
# Epoch   8 Step 11 Train CE 1.58720 Train Acc 0.47000
# Epoch   8 Step 12 Train CE 1.61175 Train Acc 0.45000
# Epoch   8 Step 13 Train CE 1.72758 Train Acc 0.36000
# Epoch   8 Step 14 Train CE 1.67395 Train Acc 0.43000
# Epoch   8 Step 15 Train CE 1.53089 Train Acc 0.45000
# Epoch   8 Step 16 Train CE 1.65692 Train Acc 0.38000
# Epoch   8 Step 17 Train CE 1.80638 Train Acc 0.28000
# Epoch   8 Step 18 Train CE 1.80757 Train Acc 0.44000
# Epoch   8 Step 19 Train CE 1.75252 Train Acc 0.28000
# Epoch   8 Step 20 Train CE 1.61844 Train Acc 0.48000
# Epoch   8 Step 21 Train CE 1.60972 Train Acc 0.37000
# Epoch   8 Step 22 Train CE 1.62789 Train Acc 0.41000
# Epoch   8 Step 23 Train CE 2.10021 Train Acc 0.20000
# Epoch   8 Step 24 Train CE 1.71852 Train Acc 0.37000
# Epoch   8 Step 25 Train CE 1.74501 Train Acc 0.33000
# Epoch   8 Step 26 Train CE 1.64148 Train Acc 0.33000
# Epoch   8 Step 27 Train CE 1.74953 Train Acc 0.22000
# Epoch   8 Step 28 Train CE 1.65686 Train Acc 0.49000
# Epoch   8 Step 29 Train CE 1.54443 Train Acc 0.39000
# Epoch   8 Step 30 Train CE 1.51257 Train Acc 0.42000
# Epoch   8 Step 31 Train CE 1.60894 Train Acc 0.35000
# Epoch   8 Step 32 Train CE 1.69050 Train Acc 0.34000
# Epoch   8 Step 33 Train CE 1.78578 Train Acc 0.37838
# Epoch   8 Validation CE 1.91683 Validation Acc 0.20764
#
# Epoch   9 Step  0 Train CE 1.99432 Train Acc 0.21000
# Epoch   9 Step  1 Train CE 1.71100 Train Acc 0.45000
# Epoch   9 Step  2 Train CE 1.63869 Train Acc 0.35000
# Epoch   9 Step  3 Train CE 1.51027 Train Acc 0.47000
# Epoch   9 Step  4 Train CE 1.60034 Train Acc 0.37000
# Epoch   9 Step  5 Train CE 1.55909 Train Acc 0.59000
# Epoch   9 Step  6 Train CE 1.80590 Train Acc 0.32000
# Epoch   9 Step  7 Train CE 1.81263 Train Acc 0.24000
# Epoch   9 Step  8 Train CE 1.70957 Train Acc 0.33000
# Epoch   9 Step  9 Train CE 1.72320 Train Acc 0.25000
# Epoch   9 Step 10 Train CE 2.00944 Train Acc 0.12000
# Epoch   9 Step 11 Train CE 1.75723 Train Acc 0.18000
# Epoch   9 Step 12 Train CE 1.65303 Train Acc 0.41000
# Epoch   9 Step 13 Train CE 1.47586 Train Acc 0.48000
# Epoch   9 Step 14 Train CE 1.57737 Train Acc 0.38000
# Epoch   9 Step 15 Train CE 1.58009 Train Acc 0.44000
# Epoch   9 Step 16 Train CE 1.82545 Train Acc 0.26000
# Epoch   9 Step 17 Train CE 1.97320 Train Acc 0.34000
# Epoch   9 Step 18 Train CE 1.53158 Train Acc 0.51000
# Epoch   9 Step 19 Train CE 1.52467 Train Acc 0.43000
# Epoch   9 Step 20 Train CE 1.43637 Train Acc 0.53000
# Epoch   9 Step 21 Train CE 1.68001 Train Acc 0.33000
# Epoch   9 Step 22 Train CE 1.56683 Train Acc 0.47000
# Epoch   9 Step 23 Train CE 1.39246 Train Acc 0.54000
# Epoch   9 Step 24 Train CE 1.57935 Train Acc 0.39000
# Epoch   9 Step 25 Train CE 1.52376 Train Acc 0.43000
# Epoch   9 Step 26 Train CE 1.58321 Train Acc 0.41000
# Epoch   9 Step 27 Train CE 1.44852 Train Acc 0.51000
# Epoch   9 Step 28 Train CE 1.62715 Train Acc 0.39000
# Epoch   9 Step 29 Train CE 2.55353 Train Acc 0.23000
# Epoch   9 Step 30 Train CE 1.82259 Train Acc 0.28000
# Epoch   9 Step 31 Train CE 1.60902 Train Acc 0.39000
# Epoch   9 Step 32 Train CE 1.57019 Train Acc 0.42000
# Epoch   9 Step 33 Train CE 1.50782 Train Acc 0.35135
# Epoch   9 Validation CE 1.71641 Validation Acc 0.29833
# Epoch  10 Step  0 Train CE 1.73932 Train Acc 0.27000
# Epoch  10 Step  1 Train CE 1.71628 Train Acc 0.38000
# Epoch  10 Step  2 Train CE 1.45076 Train Acc 0.51000
# Epoch  10 Step  3 Train CE 1.61521 Train Acc 0.38000
# Epoch  10 Step  4 Train CE 1.68640 Train Acc 0.34000
# Epoch  10 Step  5 Train CE 1.62660 Train Acc 0.44000
# Epoch  10 Step  6 Train CE 1.38634 Train Acc 0.49000
# Epoch  10 Step  7 Train CE 1.44833 Train Acc 0.44000
# Epoch  10 Step  8 Train CE 1.95562 Train Acc 0.21000
# Epoch  10 Step  9 Train CE 2.25748 Train Acc 0.16000
# Epoch  10 Step 10 Train CE 2.04157 Train Acc 0.14000
# Epoch  10 Step 11 Train CE 1.73423 Train Acc 0.37000
# Epoch  10 Step 12 Train CE 1.60745 Train Acc 0.51000
# Epoch  10 Step 13 Train CE 1.68788 Train Acc 0.31000
# Epoch  10 Step 14 Train CE 1.64827 Train Acc 0.32000
# Epoch  10 Step 15 Train CE 1.51172 Train Acc 0.43000
# Epoch  10 Step 16 Train CE 1.52855 Train Acc 0.42000
# Epoch  10 Step 17 Train CE 1.82214 Train Acc 0.25000
# Epoch  10 Step 18 Train CE 1.73823 Train Acc 0.30000
# Epoch  10 Step 19 Train CE 1.43908 Train Acc 0.56000
# Epoch  10 Step 20 Train CE 1.72873 Train Acc 0.40000
# Epoch  10 Step 21 Train CE 1.74062 Train Acc 0.30000
# Epoch  10 Step 22 Train CE 1.71246 Train Acc 0.36000
# Epoch  10 Step 23 Train CE 1.60552 Train Acc 0.43000
# Epoch  10 Step 24 Train CE 1.79057 Train Acc 0.28000
# Epoch  10 Step 25 Train CE 1.75699 Train Acc 0.35000
# Epoch  10 Step 26 Train CE 1.52966 Train Acc 0.46000
# Epoch  10 Step 27 Train CE 1.49384 Train Acc 0.41000
# Epoch  10 Step 28 Train CE 1.82661 Train Acc 0.30000
# Epoch  10 Step 29 Train CE 1.80797 Train Acc 0.36000
# Epoch  10 Step 30 Train CE 1.66208 Train Acc 0.35000
# Epoch  10 Step 31 Train CE 1.52367 Train Acc 0.53000
# Epoch  10 Step 32 Train CE 1.57501 Train Acc 0.39000
# Epoch  10 Step 33 Train CE 1.48207 Train Acc 0.43243
# Epoch  10 Validation CE 1.61696 Validation Acc 0.37947
#
# Epoch  11 Step  0 Train CE 1.52630 Train Acc 0.46000
# Epoch  11 Step  1 Train CE 1.48881 Train Acc 0.41000
# Epoch  11 Step  2 Train CE 1.50483 Train Acc 0.49000
# Epoch  11 Step  3 Train CE 1.42455 Train Acc 0.53000
# Epoch  11 Step  4 Train CE 1.57430 Train Acc 0.41000
# Epoch  11 Step  5 Train CE 1.73748 Train Acc 0.34000
# Epoch  11 Step  6 Train CE 1.94624 Train Acc 0.28000
# Epoch  11 Step  7 Train CE 1.73034 Train Acc 0.35000
# Epoch  11 Step  8 Train CE 1.71939 Train Acc 0.30000
# Epoch  11 Step  9 Train CE 1.61225 Train Acc 0.39000
# Epoch  11 Step 10 Train CE 1.45362 Train Acc 0.53000
# Epoch  11 Step 11 Train CE 1.55745 Train Acc 0.44000
# Epoch  11 Step 12 Train CE 1.59263 Train Acc 0.41000
# Epoch  11 Step 13 Train CE 1.64596 Train Acc 0.45000
# Epoch  11 Step 14 Train CE 1.64063 Train Acc 0.31000
# Epoch  11 Step 15 Train CE 1.67192 Train Acc 0.45000
# Epoch  11 Step 16 Train CE 1.63765 Train Acc 0.39000
# Epoch  11 Step 17 Train CE 1.52153 Train Acc 0.46000
# Epoch  11 Step 18 Train CE 1.67900 Train Acc 0.40000
# Epoch  11 Step 19 Train CE 1.60280 Train Acc 0.41000
# Epoch  11 Step 20 Train CE 1.55876 Train Acc 0.46000
# Epoch  11 Step 21 Train CE 1.39810 Train Acc 0.53000
# Epoch  11 Step 22 Train CE 1.48367 Train Acc 0.44000
# Epoch  11 Step 23 Train CE 1.59583 Train Acc 0.39000
# Epoch  11 Step 24 Train CE 1.52558 Train Acc 0.45000
# Epoch  11 Step 25 Train CE 1.56343 Train Acc 0.42000
# Epoch  11 Step 26 Train CE 1.84436 Train Acc 0.33000
# Epoch  11 Step 27 Train CE 1.56472 Train Acc 0.48000
# Epoch  11 Step 28 Train CE 1.43654 Train Acc 0.51000
# Epoch  11 Step 29 Train CE 1.38690 Train Acc 0.60000
# Epoch  11 Step 30 Train CE 1.64856 Train Acc 0.41000
# Epoch  11 Step 31 Train CE 1.57405 Train Acc 0.37000
# Epoch  11 Step 32 Train CE 1.45758 Train Acc 0.50000
# Epoch  11 Step 33 Train CE 1.41158 Train Acc 0.45946
# Epoch  11 Validation CE 1.40053 Validation Acc 0.49642
#
# Epoch  12 Step  0 Train CE 1.33756 Train Acc 0.48000
# Epoch  12 Step  1 Train CE 1.60462 Train Acc 0.40000
# Epoch  12 Step  2 Train CE 1.78688 Train Acc 0.34000
# Epoch  12 Step  3 Train CE 2.38497 Train Acc 0.13000
# Epoch  12 Step  4 Train CE 1.63800 Train Acc 0.44000
# Epoch  12 Step  5 Train CE 1.68846 Train Acc 0.34000
# Epoch  12 Step  6 Train CE 1.66953 Train Acc 0.43000
# Epoch  12 Step  7 Train CE 1.54507 Train Acc 0.48000
# Epoch  12 Step  8 Train CE 1.53601 Train Acc 0.49000
# Epoch  12 Step  9 Train CE 1.36930 Train Acc 0.47000
# Epoch  12 Step 10 Train CE 1.45003 Train Acc 0.52000
# Epoch  12 Step 11 Train CE 1.35001 Train Acc 0.58000
# Epoch  12 Step 12 Train CE 1.50324 Train Acc 0.49000
# Epoch  12 Step 13 Train CE 1.49859 Train Acc 0.43000
# Epoch  12 Step 14 Train CE 1.70010 Train Acc 0.38000
# Epoch  12 Step 15 Train CE 1.50828 Train Acc 0.44000
# Epoch  12 Step 16 Train CE 1.41910 Train Acc 0.47000
# Epoch  12 Step 17 Train CE 1.54686 Train Acc 0.44000
# Epoch  12 Step 18 Train CE 1.26609 Train Acc 0.53000
# Epoch  12 Step 19 Train CE 1.58783 Train Acc 0.45000
# Epoch  12 Step 20 Train CE 1.58768 Train Acc 0.51000
# Epoch  12 Step 21 Train CE 1.70225 Train Acc 0.37000
# Epoch  12 Step 22 Train CE 1.63946 Train Acc 0.37000
# Epoch  12 Step 23 Train CE 1.81234 Train Acc 0.27000
# Epoch  12 Step 24 Train CE 1.51505 Train Acc 0.46000
# Epoch  12 Step 25 Train CE 1.38672 Train Acc 0.50000
# Epoch  12 Step 26 Train CE 1.52375 Train Acc 0.44000
# Epoch  12 Step 27 Train CE 1.77644 Train Acc 0.35000
# Epoch  12 Step 28 Train CE 1.83899 Train Acc 0.30000
# Epoch  12 Step 29 Train CE 1.49827 Train Acc 0.44000
# Epoch  12 Step 30 Train CE 1.56421 Train Acc 0.41000
# Epoch  12 Step 31 Train CE 1.70572 Train Acc 0.39000
# Epoch  12 Step 32 Train CE 1.69493 Train Acc 0.35000
# Epoch  12 Step 33 Train CE 1.47186 Train Acc 0.48649
# Epoch  12 Validation CE 1.42172 Validation Acc 0.54177
#
# Epoch  13 Step  0 Train CE 1.44515 Train Acc 0.52000
# Epoch  13 Step  1 Train CE 1.52286 Train Acc 0.46000
# Epoch  13 Step  2 Train CE 1.35339 Train Acc 0.59000
# Epoch  13 Step  3 Train CE 1.43070 Train Acc 0.45000
# Epoch  13 Step  4 Train CE 1.26236 Train Acc 0.56000
# Epoch  13 Step  5 Train CE 1.44746 Train Acc 0.45000
# Epoch  13 Step  6 Train CE 1.38551 Train Acc 0.52000
# Epoch  13 Step  7 Train CE 1.41119 Train Acc 0.49000
# Epoch  13 Step  8 Train CE 1.71601 Train Acc 0.39000
# Epoch  13 Step  9 Train CE 1.59615 Train Acc 0.42000
# Epoch  13 Step 10 Train CE 1.52672 Train Acc 0.48000
# Epoch  13 Step 11 Train CE 1.81105 Train Acc 0.38000
# Epoch  13 Step 12 Train CE 1.97731 Train Acc 0.36000
# Epoch  13 Step 13 Train CE 1.71300 Train Acc 0.44000
# Epoch  13 Step 14 Train CE 1.68102 Train Acc 0.36000
# Epoch  13 Step 15 Train CE 1.63037 Train Acc 0.44000
# Epoch  13 Step 16 Train CE 1.61366 Train Acc 0.34000
# Epoch  13 Step 17 Train CE 1.70129 Train Acc 0.35000
# Epoch  13 Step 18 Train CE 1.59164 Train Acc 0.37000
# Epoch  13 Step 19 Train CE 1.52063 Train Acc 0.44000
# Epoch  13 Step 20 Train CE 1.31400 Train Acc 0.57000
# Epoch  13 Step 21 Train CE 1.53918 Train Acc 0.36000
# Epoch  13 Step 22 Train CE 1.84978 Train Acc 0.25000
# Epoch  13 Step 23 Train CE 2.05893 Train Acc 0.30000
# Epoch  13 Step 24 Train CE 2.39667 Train Acc 0.26000
# Epoch  13 Step 25 Train CE 1.84669 Train Acc 0.27000
# Epoch  13 Step 26 Train CE 1.88626 Train Acc 0.17000
# Epoch  13 Step 27 Train CE 1.80798 Train Acc 0.38000
# Epoch  13 Step 28 Train CE 1.69082 Train Acc 0.38000
# Epoch  13 Step 29 Train CE 1.69956 Train Acc 0.32000
# Epoch  13 Step 30 Train CE 1.55035 Train Acc 0.45000
# Epoch  13 Step 31 Train CE 1.66043 Train Acc 0.39000
# Epoch  13 Step 32 Train CE 1.72778 Train Acc 0.25000
# Epoch  13 Step 33 Train CE 1.49929 Train Acc 0.44595
# Epoch  13 Validation CE 1.49689 Validation Acc 0.48926
#
# Epoch  14 Step  0 Train CE 1.47105 Train Acc 0.48000
# Epoch  14 Step  1 Train CE 1.52750 Train Acc 0.45000
# Epoch  14 Step  2 Train CE 1.49268 Train Acc 0.44000
# Epoch  14 Step  3 Train CE 1.49790 Train Acc 0.44000
# Epoch  14 Step  4 Train CE 1.48419 Train Acc 0.38000
# Epoch  14 Step  5 Train CE 1.64197 Train Acc 0.34000
# Epoch  14 Step  6 Train CE 1.92198 Train Acc 0.32000
# Epoch  14 Step  7 Train CE 1.62015 Train Acc 0.45000
# Epoch  14 Step  8 Train CE 1.41023 Train Acc 0.56000
# Epoch  14 Step  9 Train CE 1.41783 Train Acc 0.43000
# Epoch  14 Step 10 Train CE 1.44216 Train Acc 0.45000
# Epoch  14 Step 11 Train CE 1.42358 Train Acc 0.51000
# Epoch  14 Step 12 Train CE 1.80819 Train Acc 0.33000
# Epoch  14 Step 13 Train CE 1.85264 Train Acc 0.26000
# Epoch  14 Step 14 Train CE 1.94322 Train Acc 0.19000
# Epoch  14 Step 15 Train CE 1.75741 Train Acc 0.39000
# Epoch  14 Step 16 Train CE 1.75171 Train Acc 0.32000
# Epoch  14 Step 17 Train CE 1.80296 Train Acc 0.21000
# Epoch  14 Step 18 Train CE 1.51727 Train Acc 0.39000
# Epoch  14 Step 19 Train CE 1.62642 Train Acc 0.45000
# Epoch  14 Step 20 Train CE 1.41688 Train Acc 0.51000
# Epoch  14 Step 21 Train CE 1.42219 Train Acc 0.57000
# Epoch  14 Step 22 Train CE 1.44875 Train Acc 0.53000
# Epoch  14 Step 23 Train CE 1.56895 Train Acc 0.42000
# Epoch  14 Step 24 Train CE 1.69699 Train Acc 0.32000
# Epoch  14 Step 25 Train CE 2.17151 Train Acc 0.15000
# Epoch  14 Step 26 Train CE 1.66388 Train Acc 0.38000
# Epoch  14 Step 27 Train CE 1.49899 Train Acc 0.54000
# Epoch  14 Step 28 Train CE 1.48664 Train Acc 0.46000
# Epoch  14 Step 29 Train CE 1.50128 Train Acc 0.46000
# Epoch  14 Step 30 Train CE 1.46129 Train Acc 0.52000
# Epoch  14 Step 31 Train CE 1.49702 Train Acc 0.35000
# Epoch  14 Step 32 Train CE 1.51584 Train Acc 0.47000
# Epoch  14 Step 33 Train CE 1.53826 Train Acc 0.44595
# Epoch  14 Validation CE 1.41190 Validation Acc 0.54893
# Epoch  15 Step  0 Train CE 1.41054 Train Acc 0.58000
# Epoch  15 Step  1 Train CE 1.31311 Train Acc 0.51000
# Epoch  15 Step  2 Train CE 1.33516 Train Acc 0.57000
# Epoch  15 Step  3 Train CE 1.38088 Train Acc 0.51000
# Epoch  15 Step  4 Train CE 1.43589 Train Acc 0.48000
# Epoch  15 Step  5 Train CE 1.87053 Train Acc 0.26000
# Epoch  15 Step  6 Train CE 2.23810 Train Acc 0.24000
# Epoch  15 Step  7 Train CE 1.89499 Train Acc 0.31000
# Epoch  15 Step  8 Train CE 1.70111 Train Acc 0.32000
# Epoch  15 Step  9 Train CE 1.47127 Train Acc 0.50000
# Epoch  15 Step 10 Train CE 1.48472 Train Acc 0.51000
# Epoch  15 Step 11 Train CE 1.36618 Train Acc 0.58000
# Epoch  15 Step 12 Train CE 1.23383 Train Acc 0.56000
# Epoch  15 Step 13 Train CE 1.41469 Train Acc 0.50000
# Epoch  15 Step 14 Train CE 1.44296 Train Acc 0.49000
# Epoch  15 Step 15 Train CE 1.62177 Train Acc 0.43000
# Epoch  15 Step 16 Train CE 2.05730 Train Acc 0.25000
# Epoch  15 Step 17 Train CE 1.53252 Train Acc 0.46000
# Epoch  15 Step 18 Train CE 1.38090 Train Acc 0.50000
# Epoch  15 Step 19 Train CE 1.36343 Train Acc 0.58000
# Epoch  15 Step 20 Train CE 1.36240 Train Acc 0.53000
# Epoch  15 Step 21 Train CE 1.32501 Train Acc 0.51000
# Epoch  15 Step 22 Train CE 1.59350 Train Acc 0.40000
# Epoch  15 Step 23 Train CE 1.46313 Train Acc 0.48000
# Epoch  15 Step 24 Train CE 1.62322 Train Acc 0.34000
# Epoch  15 Step 25 Train CE 1.82552 Train Acc 0.40000
# Epoch  15 Step 26 Train CE 1.62313 Train Acc 0.41000
# Epoch  15 Step 27 Train CE 1.46343 Train Acc 0.53000
# Epoch  15 Step 28 Train CE 1.42133 Train Acc 0.48000
# Epoch  15 Step 29 Train CE 1.41344 Train Acc 0.51000
# Epoch  15 Step 30 Train CE 1.80114 Train Acc 0.31000
# Epoch  15 Step 31 Train CE 2.10777 Train Acc 0.18000
# Epoch  15 Step 32 Train CE 1.49182 Train Acc 0.47000
# Epoch  15 Step 33 Train CE 1.64293 Train Acc 0.33784
# Epoch  15 Validation CE 1.63287 Validation Acc 0.37470
#
# Epoch  16 Step  0 Train CE 1.58896 Train Acc 0.46000
# Epoch  16 Step  1 Train CE 1.42985 Train Acc 0.51000
# Epoch  16 Step  2 Train CE 1.34953 Train Acc 0.48000
# Epoch  16 Step  3 Train CE 1.43161 Train Acc 0.57000
# Epoch  16 Step  4 Train CE 1.50865 Train Acc 0.40000
# Epoch  16 Step  5 Train CE 1.39232 Train Acc 0.57000
# Epoch  16 Step  6 Train CE 1.36008 Train Acc 0.47000
# Epoch  16 Step  7 Train CE 1.67434 Train Acc 0.38000
# Epoch  16 Step  8 Train CE 1.49068 Train Acc 0.48000
# Epoch  16 Step  9 Train CE 2.05784 Train Acc 0.29000
# Epoch  16 Step 10 Train CE 1.96852 Train Acc 0.23000
# Epoch  16 Step 11 Train CE 1.84776 Train Acc 0.30000
# Epoch  16 Step 12 Train CE 1.70897 Train Acc 0.30000
# Epoch  16 Step 13 Train CE 1.53359 Train Acc 0.51000
# Epoch  16 Step 14 Train CE 1.64715 Train Acc 0.33000
# Epoch  16 Step 15 Train CE 1.63432 Train Acc 0.32000
# Epoch  16 Step 16 Train CE 1.62312 Train Acc 0.35000
# Epoch  16 Step 17 Train CE 1.59200 Train Acc 0.45000
# Epoch  16 Step 18 Train CE 1.45614 Train Acc 0.51000
# Epoch  16 Step 19 Train CE 1.40267 Train Acc 0.52000
# Epoch  16 Step 20 Train CE 1.43827 Train Acc 0.49000
# Epoch  16 Step 21 Train CE 1.33634 Train Acc 0.53000
# Epoch  16 Step 22 Train CE 1.53254 Train Acc 0.38000
# Epoch  16 Step 23 Train CE 1.84735 Train Acc 0.40000
# Epoch  16 Step 24 Train CE 1.57437 Train Acc 0.45000
# Epoch  16 Step 25 Train CE 1.51546 Train Acc 0.43000
# Epoch  16 Step 26 Train CE 1.58300 Train Acc 0.39000
# Epoch  16 Step 27 Train CE 1.44063 Train Acc 0.55000
# Epoch  16 Step 28 Train CE 1.38107 Train Acc 0.54000
# Epoch  16 Step 29 Train CE 1.37327 Train Acc 0.46000
# Epoch  16 Step 30 Train CE 1.54425 Train Acc 0.41000
# Epoch  16 Step 31 Train CE 1.66389 Train Acc 0.41000
# Epoch  16 Step 32 Train CE 1.25843 Train Acc 0.53000
# Epoch  16 Step 33 Train CE 1.42504 Train Acc 0.43243
# Epoch  16 Validation CE 1.80477 Validation Acc 0.35561
#
# Epoch  17 Step  0 Train CE 1.64378 Train Acc 0.37000
# Epoch  17 Step  1 Train CE 1.54491 Train Acc 0.43000
# Epoch  17 Step  2 Train CE 1.30737 Train Acc 0.51000
# Epoch  17 Step  3 Train CE 1.38405 Train Acc 0.47000
# Epoch  17 Step  4 Train CE 1.43520 Train Acc 0.50000
# Epoch  17 Step  5 Train CE 1.52793 Train Acc 0.50000
# Epoch  17 Step  6 Train CE 1.82562 Train Acc 0.29000
# Epoch  17 Step  7 Train CE 2.25403 Train Acc 0.32000
# Epoch  17 Step  8 Train CE 1.86554 Train Acc 0.31000
# Epoch  17 Step  9 Train CE 1.60508 Train Acc 0.40000
# Epoch  17 Step 10 Train CE 1.65648 Train Acc 0.38000
# Epoch  17 Step 11 Train CE 1.58198 Train Acc 0.46000
# Epoch  17 Step 12 Train CE 1.53411 Train Acc 0.47000
# Epoch  17 Step 13 Train CE 1.54064 Train Acc 0.47000
# Epoch  17 Step 14 Train CE 1.46945 Train Acc 0.43000
# Epoch  17 Step 15 Train CE 1.43492 Train Acc 0.47000
# Epoch  17 Step 16 Train CE 1.64774 Train Acc 0.35000
# Epoch  17 Step 17 Train CE 1.60316 Train Acc 0.29000
# Epoch  17 Step 18 Train CE 1.71647 Train Acc 0.37000
# Epoch  17 Step 19 Train CE 1.78111 Train Acc 0.34000
# Epoch  17 Step 20 Train CE 1.56385 Train Acc 0.46000
# Epoch  17 Step 21 Train CE 1.59713 Train Acc 0.45000
# Epoch  17 Step 22 Train CE 1.51394 Train Acc 0.51000
# Epoch  17 Step 23 Train CE 1.33869 Train Acc 0.56000
# Epoch  17 Step 24 Train CE 1.45350 Train Acc 0.50000
# Epoch  17 Step 25 Train CE 1.42492 Train Acc 0.47000
# Epoch  17 Step 26 Train CE 1.50054 Train Acc 0.46000
# Epoch  17 Step 27 Train CE 1.50463 Train Acc 0.47000
# Epoch  17 Step 28 Train CE 1.53218 Train Acc 0.44000
# Epoch  17 Step 29 Train CE 1.43039 Train Acc 0.48000
# Epoch  17 Step 30 Train CE 1.23182 Train Acc 0.58000
# Epoch  17 Step 31 Train CE 1.48923 Train Acc 0.47000
# Epoch  17 Step 32 Train CE 1.69618 Train Acc 0.44000
# Epoch  17 Step 33 Train CE 1.39448 Train Acc 0.59459
# Epoch  17 Validation CE 1.35723 Validation Acc 0.52506
#
# Epoch  18 Step  0 Train CE 1.34214 Train Acc 0.56000
# Epoch  18 Step  1 Train CE 1.33319 Train Acc 0.55000
# Epoch  18 Step  2 Train CE 1.27732 Train Acc 0.53000
# Epoch  18 Step  3 Train CE 1.26584 Train Acc 0.58000
# Epoch  18 Step  4 Train CE 1.47686 Train Acc 0.45000
# Epoch  18 Step  5 Train CE 1.55566 Train Acc 0.43000
# Epoch  18 Step  6 Train CE 1.73408 Train Acc 0.37000
# Epoch  18 Step  7 Train CE 1.53166 Train Acc 0.40000
# Epoch  18 Step  8 Train CE 1.32076 Train Acc 0.54000
# Epoch  18 Step  9 Train CE 1.70763 Train Acc 0.39000
# Epoch  18 Step 10 Train CE 1.41356 Train Acc 0.53000
# Epoch  18 Step 11 Train CE 1.29940 Train Acc 0.51000
# Epoch  18 Step 12 Train CE 1.51485 Train Acc 0.38000
# Epoch  18 Step 13 Train CE 1.52754 Train Acc 0.46000
# Epoch  18 Step 14 Train CE 1.52130 Train Acc 0.49000
# Epoch  18 Step 15 Train CE 1.66952 Train Acc 0.39000
# Epoch  18 Step 16 Train CE 1.79602 Train Acc 0.34000
# Epoch  18 Step 17 Train CE 2.13485 Train Acc 0.18000
# Epoch  18 Step 18 Train CE 2.15509 Train Acc 0.26000
# Epoch  18 Step 19 Train CE 1.89810 Train Acc 0.31000
# Epoch  18 Step 20 Train CE 1.64568 Train Acc 0.42000
# Epoch  18 Step 21 Train CE 1.62456 Train Acc 0.38000
# Epoch  18 Step 22 Train CE 1.63446 Train Acc 0.42000
# Epoch  18 Step 23 Train CE 1.49415 Train Acc 0.44000
# Epoch  18 Step 24 Train CE 1.47387 Train Acc 0.45000
# Epoch  18 Step 25 Train CE 1.52571 Train Acc 0.45000
# Epoch  18 Step 26 Train CE 1.66924 Train Acc 0.34000
# Epoch  18 Step 27 Train CE 1.37213 Train Acc 0.59000
# Epoch  18 Step 28 Train CE 1.65453 Train Acc 0.41000
# Epoch  18 Step 29 Train CE 1.61275 Train Acc 0.35000
# Epoch  18 Step 30 Train CE 1.46756 Train Acc 0.42000
# Epoch  18 Step 31 Train CE 1.39922 Train Acc 0.55000
# Epoch  18 Step 32 Train CE 1.52473 Train Acc 0.40000
# Epoch  18 Step 33 Train CE 1.32920 Train Acc 0.52703
# Epoch  18 Validation CE 1.48294 Validation Acc 0.43198
#
# Epoch  19 Step  0 Train CE 1.64103 Train Acc 0.37000
# Epoch  19 Step  1 Train CE 2.08886 Train Acc 0.40000
# Epoch  19 Step  2 Train CE 1.59473 Train Acc 0.45000
# Epoch  19 Step  3 Train CE 1.60056 Train Acc 0.33000
# Epoch  19 Step  4 Train CE 1.37573 Train Acc 0.54000
# Epoch  19 Step  5 Train CE 1.32893 Train Acc 0.58000
# Epoch  19 Step  6 Train CE 1.27511 Train Acc 0.53000
# Epoch  19 Step  7 Train CE 1.56360 Train Acc 0.39000
# Epoch  19 Step  8 Train CE 1.41484 Train Acc 0.51000
# Epoch  19 Step  9 Train CE 1.96231 Train Acc 0.28000
# Epoch  19 Step 10 Train CE 1.77416 Train Acc 0.38000
# Epoch  19 Step 11 Train CE 1.44229 Train Acc 0.48000
# Epoch  19 Step 12 Train CE 1.51002 Train Acc 0.44000
# Epoch  19 Step 13 Train CE 1.56181 Train Acc 0.40000
# Epoch  19 Step 14 Train CE 1.47444 Train Acc 0.42000
# Epoch  19 Step 15 Train CE 1.52220 Train Acc 0.38000
# Epoch  19 Step 16 Train CE 1.52319 Train Acc 0.45000
# Epoch  19 Step 17 Train CE 1.63296 Train Acc 0.40000
# Epoch  19 Step 18 Train CE 1.46859 Train Acc 0.43000
# Epoch  19 Step 19 Train CE 1.36436 Train Acc 0.53000
# Epoch  19 Step 20 Train CE 1.63934 Train Acc 0.35000
# Epoch  19 Step 21 Train CE 1.71310 Train Acc 0.32000
# Epoch  19 Step 22 Train CE 1.48033 Train Acc 0.46000
# Epoch  19 Step 23 Train CE 1.46896 Train Acc 0.46000
# Epoch  19 Step 24 Train CE 1.45135 Train Acc 0.47000
# Epoch  19 Step 25 Train CE 1.45274 Train Acc 0.52000
# Epoch  19 Step 26 Train CE 1.36005 Train Acc 0.52000
# Epoch  19 Step 27 Train CE 1.44298 Train Acc 0.52000
# Epoch  19 Step 28 Train CE 1.17540 Train Acc 0.65000
# Epoch  19 Step 29 Train CE 1.37825 Train Acc 0.48000
# Epoch  19 Step 30 Train CE 1.40976 Train Acc 0.49000
# Epoch  19 Step 31 Train CE 1.43643 Train Acc 0.52000
# Epoch  19 Step 32 Train CE 1.94386 Train Acc 0.32000
# Epoch  19 Step 33 Train CE 1.29686 Train Acc 0.56757
# Epoch  19 Validation CE 1.41688 Validation Acc 0.47017
# Epoch  20 Step  0 Train CE 1.40912 Train Acc 0.47000
# Epoch  20 Step  1 Train CE 1.48156 Train Acc 0.43000
# Epoch  20 Step  2 Train CE 1.49126 Train Acc 0.46000
# Epoch  20 Step  3 Train CE 1.47493 Train Acc 0.46000
# Epoch  20 Step  4 Train CE 1.31204 Train Acc 0.56000
# Epoch  20 Step  5 Train CE 1.46469 Train Acc 0.45000
# Epoch  20 Step  6 Train CE 1.28579 Train Acc 0.57000
# Epoch  20 Step  7 Train CE 1.45609 Train Acc 0.47000
# Epoch  20 Step  8 Train CE 1.69275 Train Acc 0.42000
# Epoch  20 Step  9 Train CE 1.16461 Train Acc 0.62000
# Epoch  20 Step 10 Train CE 1.59496 Train Acc 0.39000
# Epoch  20 Step 11 Train CE 1.55734 Train Acc 0.37000
# Epoch  20 Step 12 Train CE 1.61138 Train Acc 0.35000
# Epoch  20 Step 13 Train CE 1.95610 Train Acc 0.32000
# Epoch  20 Step 14 Train CE 1.86635 Train Acc 0.25000
# Epoch  20 Step 15 Train CE 1.62390 Train Acc 0.40000
# Epoch  20 Step 16 Train CE 1.45171 Train Acc 0.54000
# Epoch  20 Step 17 Train CE 1.24355 Train Acc 0.58000
# Epoch  20 Step 18 Train CE 1.33345 Train Acc 0.45000
# Epoch  20 Step 19 Train CE 1.33334 Train Acc 0.52000
# Epoch  20 Step 20 Train CE 1.31430 Train Acc 0.57000
# Epoch  20 Step 21 Train CE 1.13531 Train Acc 0.62000
# Epoch  20 Step 22 Train CE 1.24252 Train Acc 0.54000
# Epoch  20 Step 23 Train CE 1.42376 Train Acc 0.51000
# Epoch  20 Step 24 Train CE 1.65216 Train Acc 0.49000
# Epoch  20 Step 25 Train CE 1.70250 Train Acc 0.34000
# Epoch  20 Step 26 Train CE 1.39168 Train Acc 0.55000
# Epoch  20 Step 27 Train CE 1.31368 Train Acc 0.58000
# Epoch  20 Step 28 Train CE 1.36704 Train Acc 0.52000
# Epoch  20 Step 29 Train CE 1.33789 Train Acc 0.55000
# Epoch  20 Step 30 Train CE 1.26724 Train Acc 0.60000
# Epoch  20 Step 31 Train CE 1.19046 Train Acc 0.55000
# Epoch  20 Step 32 Train CE 1.35211 Train Acc 0.52000
# Epoch  20 Step 33 Train CE 1.22003 Train Acc 0.54054
# Epoch  20 Validation CE 1.22443 Validation Acc 0.57279
#
# Epoch  21 Step  0 Train CE 1.24879 Train Acc 0.56000
# Epoch  21 Step  1 Train CE 1.21685 Train Acc 0.50000
# Epoch  21 Step  2 Train CE 1.30183 Train Acc 0.53000
# Epoch  21 Step  3 Train CE 1.55513 Train Acc 0.47000
# Epoch  21 Step  4 Train CE 1.29112 Train Acc 0.53000
# Epoch  21 Step  5 Train CE 1.28891 Train Acc 0.53000
# Epoch  21 Step  6 Train CE 1.44609 Train Acc 0.43000
# Epoch  21 Step  7 Train CE 1.56205 Train Acc 0.47000
# Epoch  21 Step  8 Train CE 1.49052 Train Acc 0.41000
# Epoch  21 Step  9 Train CE 1.38599 Train Acc 0.57000
# Epoch  21 Step 10 Train CE 1.35019 Train Acc 0.55000
# Epoch  21 Step 11 Train CE 1.55139 Train Acc 0.49000
# Epoch  21 Step 12 Train CE 2.03497 Train Acc 0.31000
# Epoch  21 Step 13 Train CE 1.53003 Train Acc 0.36000
# Epoch  21 Step 14 Train CE 1.47009 Train Acc 0.41000
# Epoch  21 Step 15 Train CE 1.43446 Train Acc 0.47000
# Epoch  21 Step 16 Train CE 1.32325 Train Acc 0.52000
# Epoch  21 Step 17 Train CE 1.13594 Train Acc 0.62000
# Epoch  21 Step 18 Train CE 1.29555 Train Acc 0.53000
# Epoch  21 Step 19 Train CE 1.60000 Train Acc 0.35000
# Epoch  21 Step 20 Train CE 1.95084 Train Acc 0.42000
# Epoch  21 Step 21 Train CE 1.79264 Train Acc 0.32000
# Epoch  21 Step 22 Train CE 1.61732 Train Acc 0.43000
# Epoch  21 Step 23 Train CE 1.49356 Train Acc 0.51000
# Epoch  21 Step 24 Train CE 1.35259 Train Acc 0.50000
# Epoch  21 Step 25 Train CE 1.29345 Train Acc 0.58000
# Epoch  21 Step 26 Train CE 1.34174 Train Acc 0.51000
# Epoch  21 Step 27 Train CE 1.27004 Train Acc 0.53000
# Epoch  21 Step 28 Train CE 1.25785 Train Acc 0.53000
# Epoch  21 Step 29 Train CE 1.33179 Train Acc 0.50000
# Epoch  21 Step 30 Train CE 1.34636 Train Acc 0.54000
# Epoch  21 Step 31 Train CE 1.70110 Train Acc 0.41000
# Epoch  21 Step 32 Train CE 1.83036 Train Acc 0.40000
# Epoch  21 Step 33 Train CE 1.76794 Train Acc 0.44595
# Epoch  21 Validation CE 1.60408 Validation Acc 0.39141
#
# Epoch  22 Step  0 Train CE 1.63222 Train Acc 0.37000
# Epoch  22 Step  1 Train CE 1.44527 Train Acc 0.50000
# Epoch  22 Step  2 Train CE 1.41711 Train Acc 0.50000
# Epoch  22 Step  3 Train CE 1.23420 Train Acc 0.61000
# Epoch  22 Step  4 Train CE 1.24025 Train Acc 0.56000
# Epoch  22 Step  5 Train CE 1.30117 Train Acc 0.51000
# Epoch  22 Step  6 Train CE 1.36198 Train Acc 0.56000
# Epoch  22 Step  7 Train CE 1.90479 Train Acc 0.28000
# Epoch  22 Step  8 Train CE 1.58426 Train Acc 0.35000
# Epoch  22 Step  9 Train CE 1.46035 Train Acc 0.46000
# Epoch  22 Step 10 Train CE 1.38062 Train Acc 0.52000
# Epoch  22 Step 11 Train CE 1.28134 Train Acc 0.52000
# Epoch  22 Step 12 Train CE 1.16162 Train Acc 0.65000
# Epoch  22 Step 13 Train CE 1.31392 Train Acc 0.51000
# Epoch  22 Step 14 Train CE 1.29400 Train Acc 0.53000
# Epoch  22 Step 15 Train CE 1.31103 Train Acc 0.54000
# Epoch  22 Step 16 Train CE 1.51677 Train Acc 0.42000
# Epoch  22 Step 17 Train CE 1.34880 Train Acc 0.50000
# Epoch  22 Step 18 Train CE 1.31297 Train Acc 0.54000
# Epoch  22 Step 19 Train CE 1.29803 Train Acc 0.54000
# Epoch  22 Step 20 Train CE 1.25784 Train Acc 0.51000
# Epoch  22 Step 21 Train CE 1.35230 Train Acc 0.51000
# Epoch  22 Step 22 Train CE 1.56169 Train Acc 0.49000
# Epoch  22 Step 23 Train CE 1.25729 Train Acc 0.57000
# Epoch  22 Step 24 Train CE 1.28006 Train Acc 0.56000
# Epoch  22 Step 25 Train CE 1.36772 Train Acc 0.50000
# Epoch  22 Step 26 Train CE 1.24198 Train Acc 0.54000
# Epoch  22 Step 27 Train CE 1.36585 Train Acc 0.48000
# Epoch  22 Step 28 Train CE 1.75069 Train Acc 0.43000
# Epoch  22 Step 29 Train CE 1.38805 Train Acc 0.47000
# Epoch  22 Step 30 Train CE 1.22574 Train Acc 0.57000
# Epoch  22 Step 31 Train CE 1.38324 Train Acc 0.49000
# Epoch  22 Step 32 Train CE 1.36856 Train Acc 0.52000
# Epoch  22 Step 33 Train CE 1.17921 Train Acc 0.64865
# Epoch  22 Validation CE 1.22546 Validation Acc 0.56802
#
# Epoch  23 Step  0 Train CE 1.15623 Train Acc 0.61000
# Epoch  23 Step  1 Train CE 1.17847 Train Acc 0.57000
# Epoch  23 Step  2 Train CE 1.64074 Train Acc 0.42000
# Epoch  23 Step  3 Train CE 1.76418 Train Acc 0.31000
# Epoch  23 Step  4 Train CE 2.66749 Train Acc 0.14000
# Epoch  23 Step  5 Train CE 2.43225 Train Acc 0.29000
# Epoch  23 Step  6 Train CE 1.76214 Train Acc 0.34000
# Epoch  23 Step  7 Train CE 1.68813 Train Acc 0.41000
# Epoch  23 Step  8 Train CE 1.75306 Train Acc 0.37000
# Epoch  23 Step  9 Train CE 1.71736 Train Acc 0.35000
# Epoch  23 Step 10 Train CE 1.62037 Train Acc 0.47000
# Epoch  23 Step 11 Train CE 1.56730 Train Acc 0.50000
# Epoch  23 Step 12 Train CE 1.67014 Train Acc 0.41000
# Epoch  23 Step 13 Train CE 1.59762 Train Acc 0.43000
# Epoch  23 Step 14 Train CE 1.63362 Train Acc 0.41000
# Epoch  23 Step 15 Train CE 1.69494 Train Acc 0.32000
# Epoch  23 Step 16 Train CE 1.90988 Train Acc 0.24000
# Epoch  23 Step 17 Train CE 1.56234 Train Acc 0.48000
# Epoch  23 Step 18 Train CE 1.59760 Train Acc 0.37000
# Epoch  23 Step 19 Train CE 1.54097 Train Acc 0.43000
# Epoch  23 Step 20 Train CE 1.61187 Train Acc 0.37000
# Epoch  23 Step 21 Train CE 1.69945 Train Acc 0.34000
# Epoch  23 Step 22 Train CE 1.41816 Train Acc 0.46000
# Epoch  23 Step 23 Train CE 1.56898 Train Acc 0.41000
# Epoch  23 Step 24 Train CE 1.52548 Train Acc 0.40000
# Epoch  23 Step 25 Train CE 1.57678 Train Acc 0.38000
# Epoch  23 Step 26 Train CE 1.78536 Train Acc 0.25000
# Epoch  23 Step 27 Train CE 1.96186 Train Acc 0.29000
# Epoch  23 Step 28 Train CE 1.92248 Train Acc 0.24000
# Epoch  23 Step 29 Train CE 1.69742 Train Acc 0.42000
# Epoch  23 Step 30 Train CE 1.63098 Train Acc 0.37000
# Epoch  23 Step 31 Train CE 1.52986 Train Acc 0.44000
# Epoch  23 Step 32 Train CE 1.41056 Train Acc 0.55000
# Epoch  23 Step 33 Train CE 1.44378 Train Acc 0.45946
# Epoch  23 Validation CE 1.41699 Validation Acc 0.46539
#
# Epoch  24 Step  0 Train CE 1.48931 Train Acc 0.39000
# Epoch  24 Step  1 Train CE 1.25110 Train Acc 0.58000
# Epoch  24 Step  2 Train CE 1.45370 Train Acc 0.44000
# Epoch  24 Step  3 Train CE 1.50083 Train Acc 0.48000
# Epoch  24 Step  4 Train CE 1.41642 Train Acc 0.45000
# Epoch  24 Step  5 Train CE 1.37715 Train Acc 0.45000
# Epoch  24 Step  6 Train CE 1.56359 Train Acc 0.41000
# Epoch  24 Step  7 Train CE 1.59091 Train Acc 0.30000
# Epoch  24 Step  8 Train CE 1.65273 Train Acc 0.29000
# Epoch  24 Step  9 Train CE 1.32962 Train Acc 0.51000
# Epoch  24 Step 10 Train CE 1.40874 Train Acc 0.55000
# Epoch  24 Step 11 Train CE 1.31749 Train Acc 0.47000
# Epoch  24 Step 12 Train CE 1.52103 Train Acc 0.43000
# Epoch  24 Step 13 Train CE 1.51631 Train Acc 0.46000
# Epoch  24 Step 14 Train CE 1.36728 Train Acc 0.48000
# Epoch  24 Step 15 Train CE 1.48651 Train Acc 0.52000
# Epoch  24 Step 16 Train CE 1.38535 Train Acc 0.49000
# Epoch  24 Step 17 Train CE 1.68152 Train Acc 0.40000
# Epoch  24 Step 18 Train CE 2.21506 Train Acc 0.20000
# Epoch  24 Step 19 Train CE 2.41350 Train Acc 0.16000
# Epoch  24 Step 20 Train CE 1.90556 Train Acc 0.36000
# Epoch  24 Step 21 Train CE 1.81289 Train Acc 0.30000
# Epoch  24 Step 22 Train CE 1.66486 Train Acc 0.42000
# Epoch  24 Step 23 Train CE 1.46846 Train Acc 0.42000
# Epoch  24 Step 24 Train CE 1.44814 Train Acc 0.49000
# Epoch  24 Step 25 Train CE 1.49948 Train Acc 0.47000
# Epoch  24 Step 26 Train CE 1.50230 Train Acc 0.46000
# Epoch  24 Step 27 Train CE 1.41131 Train Acc 0.53000
# Epoch  24 Step 28 Train CE 1.41202 Train Acc 0.47000
# Epoch  24 Step 29 Train CE 1.69786 Train Acc 0.36000
# Epoch  24 Step 30 Train CE 1.76901 Train Acc 0.23000
# Epoch  24 Step 31 Train CE 1.46804 Train Acc 0.48000
# Epoch  24 Step 32 Train CE 1.41049 Train Acc 0.44000
# Epoch  24 Step 33 Train CE 1.37425 Train Acc 0.44595
# Epoch  24 Validation CE 1.32225 Validation Acc 0.57041
# Epoch  25 Step  0 Train CE 1.42352 Train Acc 0.55000
# Epoch  25 Step  1 Train CE 1.32140 Train Acc 0.55000
# Epoch  25 Step  2 Train CE 1.33986 Train Acc 0.49000
# Epoch  25 Step  3 Train CE 1.25735 Train Acc 0.65000
# Epoch  25 Step  4 Train CE 1.19203 Train Acc 0.59000
# Epoch  25 Step  5 Train CE 1.18989 Train Acc 0.64000
# Epoch  25 Step  6 Train CE 1.10093 Train Acc 0.63000
# Epoch  25 Step  7 Train CE 1.18487 Train Acc 0.56000
# Epoch  25 Step  8 Train CE 1.32008 Train Acc 0.49000
# Epoch  25 Step  9 Train CE 1.05530 Train Acc 0.60000
# Epoch  25 Step 10 Train CE 1.40929 Train Acc 0.47000
# Epoch  25 Step 11 Train CE 1.48267 Train Acc 0.45000
# Epoch  25 Step 12 Train CE 1.34441 Train Acc 0.50000
# Epoch  25 Step 13 Train CE 1.46795 Train Acc 0.46000
# Epoch  25 Step 14 Train CE 1.42066 Train Acc 0.45000
# Epoch  25 Step 15 Train CE 1.82328 Train Acc 0.30000
# Epoch  25 Step 16 Train CE 1.55543 Train Acc 0.43000
# Epoch  25 Step 17 Train CE 2.34120 Train Acc 0.23000
# Epoch  25 Step 18 Train CE 2.01321 Train Acc 0.18000
# Epoch  25 Step 19 Train CE 1.70768 Train Acc 0.27000
# Epoch  25 Step 20 Train CE 1.68636 Train Acc 0.31000
# Epoch  25 Step 21 Train CE 1.42813 Train Acc 0.49000
# Epoch  25 Step 22 Train CE 1.42031 Train Acc 0.46000
# Epoch  25 Step 23 Train CE 1.45241 Train Acc 0.44000
# Epoch  25 Step 24 Train CE 1.30367 Train Acc 0.59000
# Epoch  25 Step 25 Train CE 1.32736 Train Acc 0.53000
# Epoch  25 Step 26 Train CE 1.29255 Train Acc 0.55000
# Epoch  25 Step 27 Train CE 1.16516 Train Acc 0.63000
# Epoch  25 Step 28 Train CE 1.28980 Train Acc 0.53000
# ...
# Epoch  94 Step 19 Train CE 1.11615 Train Acc 0.57000
# Epoch  94 Step 20 Train CE 1.09037 Train Acc 0.56000
# Epoch  94 Step 21 Train CE 0.82367 Train Acc 0.74000
# Epoch  94 Step 22 Train CE 0.91147 Train Acc 0.64000
# Epoch  94 Step 23 Train CE 0.84677 Train Acc 0.67000
# Epoch  94 Step 24 Train CE 0.73901 Train Acc 0.76000
# Epoch  94 Step 25 Train CE 1.05762 Train Acc 0.62000
# Epoch  94 Step 26 Train CE 0.86708 Train Acc 0.65000
# Epoch  94 Step 27 Train CE 0.84123 Train Acc 0.69000
# Epoch  94 Step 28 Train CE 0.91805 Train Acc 0.65000
# Epoch  94 Step 29 Train CE 0.95286 Train Acc 0.65000
# Epoch  94 Step 30 Train CE 1.03903 Train Acc 0.61000
# Epoch  94 Step 31 Train CE 0.97512 Train Acc 0.64000
# Epoch  94 Step 32 Train CE 1.00802 Train Acc 0.68000
# Epoch  94 Step 33 Train CE 0.95348 Train Acc 0.67568
# Epoch  94 Validation CE 0.99924 Validation Acc 0.62053
# Epoch  95 Step  0 Train CE 0.97133 Train Acc 0.63000
# Epoch  95 Step  1 Train CE 0.96915 Train Acc 0.60000
# Epoch  95 Step  2 Train CE 1.06003 Train Acc 0.62000
# Epoch  95 Step  3 Train CE 0.77528 Train Acc 0.76000
# Epoch  95 Step  4 Train CE 0.90400 Train Acc 0.68000
# Epoch  95 Step  5 Train CE 1.11243 Train Acc 0.62000
# Epoch  95 Step  6 Train CE 1.07262 Train Acc 0.52000
# Epoch  95 Step  7 Train CE 1.09532 Train Acc 0.60000
# Epoch  95 Step  8 Train CE 1.13430 Train Acc 0.64000
# Epoch  95 Step  9 Train CE 1.04527 Train Acc 0.65000
# Epoch  95 Step 10 Train CE 0.96332 Train Acc 0.66000
# Epoch  95 Step 11 Train CE 0.94728 Train Acc 0.65000
# Epoch  95 Step 12 Train CE 0.86190 Train Acc 0.70000
# Epoch  95 Step 13 Train CE 0.94184 Train Acc 0.62000
# Epoch  95 Step 14 Train CE 1.06420 Train Acc 0.60000
# Epoch  95 Step 15 Train CE 0.95909 Train Acc 0.67000
# Epoch  95 Step 16 Train CE 1.06094 Train Acc 0.66000
# Epoch  95 Step 17 Train CE 1.27883 Train Acc 0.52000
# Epoch  95 Step 18 Train CE 0.96188 Train Acc 0.70000
# Epoch  95 Step 19 Train CE 0.99191 Train Acc 0.66000
# Epoch  95 Step 20 Train CE 0.82411 Train Acc 0.69000
# Epoch  95 Step 21 Train CE 1.05962 Train Acc 0.60000
# Epoch  95 Step 22 Train CE 1.28670 Train Acc 0.54000
# Epoch  95 Step 23 Train CE 1.34490 Train Acc 0.56000
# Epoch  95 Step 24 Train CE 1.03200 Train Acc 0.61000
# Epoch  95 Step 25 Train CE 0.90628 Train Acc 0.69000
# Epoch  95 Step 26 Train CE 0.92390 Train Acc 0.67000
# Epoch  95 Step 27 Train CE 0.83420 Train Acc 0.73000
# Epoch  95 Step 28 Train CE 0.99396 Train Acc 0.63000
# Epoch  95 Step 29 Train CE 1.05270 Train Acc 0.67000
# Epoch  95 Step 30 Train CE 1.08599 Train Acc 0.59000
# Epoch  95 Step 31 Train CE 1.03389 Train Acc 0.65000
# Epoch  95 Step 32 Train CE 0.75804 Train Acc 0.74000
# Epoch  95 Step 33 Train CE 0.91528 Train Acc 0.64865
# Epoch  95 Validation CE 0.97868 Validation Acc 0.63007
#
# Epoch  96 Step  0 Train CE 0.80042 Train Acc 0.73000
# Epoch  96 Step  1 Train CE 1.15472 Train Acc 0.60000
# Epoch  96 Step  2 Train CE 0.94785 Train Acc 0.68000
# Epoch  96 Step  3 Train CE 0.81319 Train Acc 0.70000
# Epoch  96 Step  4 Train CE 1.00128 Train Acc 0.66000
# Epoch  96 Step  5 Train CE 0.85887 Train Acc 0.66000
# Epoch  96 Step  6 Train CE 0.98124 Train Acc 0.65000
# Epoch  96 Step  7 Train CE 1.05989 Train Acc 0.58000
# Epoch  96 Step  8 Train CE 1.19340 Train Acc 0.61000
# Epoch  96 Step  9 Train CE 1.23374 Train Acc 0.56000
# Epoch  96 Step 10 Train CE 1.23729 Train Acc 0.55000
# Epoch  96 Step 11 Train CE 1.15808 Train Acc 0.53000
# Epoch  96 Step 12 Train CE 1.01404 Train Acc 0.62000
# Epoch  96 Step 13 Train CE 1.02989 Train Acc 0.61000
# Epoch  96 Step 14 Train CE 1.04494 Train Acc 0.62000
# Epoch  96 Step 15 Train CE 1.08294 Train Acc 0.67000
# Epoch  96 Step 16 Train CE 1.15100 Train Acc 0.57000
# Epoch  96 Step 17 Train CE 0.95114 Train Acc 0.66000
# Epoch  96 Step 18 Train CE 0.84766 Train Acc 0.69000
# Epoch  96 Step 19 Train CE 1.10603 Train Acc 0.58000
# Epoch  96 Step 20 Train CE 1.03560 Train Acc 0.61000
# Epoch  96 Step 21 Train CE 0.90269 Train Acc 0.73000
# Epoch  96 Step 22 Train CE 0.91464 Train Acc 0.66000
# Epoch  96 Step 23 Train CE 0.94186 Train Acc 0.66000
# Epoch  96 Step 24 Train CE 1.10855 Train Acc 0.59000
# Epoch  96 Step 25 Train CE 0.79493 Train Acc 0.71000
# Epoch  96 Step 26 Train CE 1.05924 Train Acc 0.63000
# Epoch  96 Step 27 Train CE 1.02984 Train Acc 0.62000
# Epoch  96 Step 28 Train CE 0.93011 Train Acc 0.63000
# Epoch  96 Step 29 Train CE 0.88256 Train Acc 0.68000
# Epoch  96 Step 30 Train CE 0.87184 Train Acc 0.68000
# Epoch  96 Step 31 Train CE 0.73822 Train Acc 0.72000
# Epoch  96 Step 32 Train CE 1.05909 Train Acc 0.60000
# Epoch  96 Step 33 Train CE 1.30962 Train Acc 0.58108
# Epoch  96 Validation CE 1.46524 Validation Acc 0.52267
#
# Epoch  97 Step  0 Train CE 1.53706 Train Acc 0.54000
# Epoch  97 Step  1 Train CE 1.37103 Train Acc 0.45000
# Epoch  97 Step  2 Train CE 1.43258 Train Acc 0.57000
# Epoch  97 Step  3 Train CE 1.19319 Train Acc 0.49000
# Epoch  97 Step  4 Train CE 1.03331 Train Acc 0.60000
# Epoch  97 Step  5 Train CE 0.89166 Train Acc 0.68000
# Epoch  97 Step  6 Train CE 0.85869 Train Acc 0.67000
# Epoch  97 Step  7 Train CE 1.10008 Train Acc 0.63000
# Epoch  97 Step  8 Train CE 0.91426 Train Acc 0.71000
# Epoch  97 Step  9 Train CE 1.00611 Train Acc 0.60000
# Epoch  97 Step 10 Train CE 0.97933 Train Acc 0.61000
# Epoch  97 Step 11 Train CE 1.18479 Train Acc 0.60000
# Epoch  97 Step 12 Train CE 1.12625 Train Acc 0.53000
# Epoch  97 Step 13 Train CE 1.30182 Train Acc 0.45000
# Epoch  97 Step 14 Train CE 1.32983 Train Acc 0.56000
# Epoch  97 Step 15 Train CE 1.11079 Train Acc 0.62000
# Epoch  97 Step 16 Train CE 1.20369 Train Acc 0.57000
# Epoch  97 Step 17 Train CE 1.06050 Train Acc 0.57000
# Epoch  97 Step 18 Train CE 0.92766 Train Acc 0.64000
# Epoch  97 Step 19 Train CE 0.88951 Train Acc 0.67000
# Epoch  97 Step 20 Train CE 0.79223 Train Acc 0.69000
# Epoch  97 Step 21 Train CE 1.08094 Train Acc 0.54000
# Epoch  97 Step 22 Train CE 0.91283 Train Acc 0.68000
# Epoch  97 Step 23 Train CE 0.98567 Train Acc 0.59000
# Epoch  97 Step 24 Train CE 1.08606 Train Acc 0.56000
# Epoch  97 Step 25 Train CE 1.06598 Train Acc 0.67000
# Epoch  97 Step 26 Train CE 0.78582 Train Acc 0.71000
# Epoch  97 Step 27 Train CE 1.05900 Train Acc 0.63000
# Epoch  97 Step 28 Train CE 0.98571 Train Acc 0.68000
# Epoch  97 Step 29 Train CE 1.13881 Train Acc 0.57000
# Epoch  97 Step 30 Train CE 1.24811 Train Acc 0.56000
# Epoch  97 Step 31 Train CE 0.94115 Train Acc 0.65000
# Epoch  97 Step 32 Train CE 0.99906 Train Acc 0.61000
# Epoch  97 Step 33 Train CE 0.93054 Train Acc 0.67568
# Epoch  97 Validation CE 0.98959 Validation Acc 0.62768
#
# Epoch  98 Step  0 Train CE 0.90449 Train Acc 0.70000
# Epoch  98 Step  1 Train CE 0.78305 Train Acc 0.70000
# Epoch  98 Step  2 Train CE 1.07933 Train Acc 0.66000
# Epoch  98 Step  3 Train CE 0.95032 Train Acc 0.64000
# Epoch  98 Step  4 Train CE 0.83507 Train Acc 0.74000
# Epoch  98 Step  5 Train CE 0.90105 Train Acc 0.62000
# Epoch  98 Step  6 Train CE 0.87492 Train Acc 0.68000
# Epoch  98 Step  7 Train CE 0.93130 Train Acc 0.61000
# Epoch  98 Step  8 Train CE 0.79547 Train Acc 0.76000
# Epoch  98 Step  9 Train CE 0.85916 Train Acc 0.66000
# Epoch  98 Step 10 Train CE 0.72782 Train Acc 0.73000
# Epoch  98 Step 11 Train CE 0.90894 Train Acc 0.72000
# Epoch  98 Step 12 Train CE 0.95138 Train Acc 0.65000
# Epoch  98 Step 13 Train CE 1.01841 Train Acc 0.63000
# Epoch  98 Step 14 Train CE 0.92458 Train Acc 0.62000
# Epoch  98 Step 15 Train CE 0.93449 Train Acc 0.68000
# Epoch  98 Step 16 Train CE 1.02165 Train Acc 0.60000
# Epoch  98 Step 17 Train CE 1.16560 Train Acc 0.52000
# Epoch  98 Step 18 Train CE 1.33900 Train Acc 0.53000
# Epoch  98 Step 19 Train CE 1.44130 Train Acc 0.41000
# Epoch  98 Step 20 Train CE 1.45523 Train Acc 0.50000
# Epoch  98 Step 21 Train CE 1.36158 Train Acc 0.41000
# Epoch  98 Step 22 Train CE 1.16754 Train Acc 0.57000
# Epoch  98 Step 23 Train CE 1.05019 Train Acc 0.61000
# Epoch  98 Step 24 Train CE 1.04466 Train Acc 0.63000
# Epoch  98 Step 25 Train CE 1.22176 Train Acc 0.53000
# Epoch  98 Step 26 Train CE 1.04839 Train Acc 0.61000
# Epoch  98 Step 27 Train CE 0.90011 Train Acc 0.65000
# Epoch  98 Step 28 Train CE 1.05705 Train Acc 0.59000
# Epoch  98 Step 29 Train CE 0.93499 Train Acc 0.70000
# Epoch  98 Step 30 Train CE 0.77813 Train Acc 0.73000
# Epoch  98 Step 31 Train CE 0.91528 Train Acc 0.70000
# Epoch  98 Step 32 Train CE 1.04104 Train Acc 0.57000
# Epoch  98 Step 33 Train CE 1.07124 Train Acc 0.60811
# Epoch  98 Validation CE 0.98234 Validation Acc 0.63484
#
# Epoch  99 Step  0 Train CE 1.10138 Train Acc 0.57000
# Epoch  99 Step  1 Train CE 0.78631 Train Acc 0.71000
# Epoch  99 Step  2 Train CE 0.87224 Train Acc 0.65000
# Epoch  99 Step  3 Train CE 0.98802 Train Acc 0.64000
# Epoch  99 Step  4 Train CE 0.92989 Train Acc 0.63000
# Epoch  99 Step  5 Train CE 0.93406 Train Acc 0.66000
# Epoch  99 Step  6 Train CE 0.87013 Train Acc 0.70000
# Epoch  99 Step  7 Train CE 0.80539 Train Acc 0.72000
# Epoch  99 Step  8 Train CE 0.93249 Train Acc 0.63000
# Epoch  99 Step  9 Train CE 0.95714 Train Acc 0.63000
# Epoch  99 Step 10 Train CE 0.88351 Train Acc 0.69000
# Epoch  99 Step 11 Train CE 0.86956 Train Acc 0.71000
# Epoch  99 Step 12 Train CE 1.16770 Train Acc 0.61000
# Epoch  99 Step 13 Train CE 1.44882 Train Acc 0.54000
# Epoch  99 Step 14 Train CE 1.27480 Train Acc 0.55000
# Epoch  99 Step 15 Train CE 1.21370 Train Acc 0.59000
# Epoch  99 Step 16 Train CE 1.11618 Train Acc 0.60000
# Epoch  99 Step 17 Train CE 1.14301 Train Acc 0.58000
# Epoch  99 Step 18 Train CE 0.88806 Train Acc 0.63000
# Epoch  99 Step 19 Train CE 0.84827 Train Acc 0.75000
# Epoch  99 Step 20 Train CE 0.96165 Train Acc 0.67000
# Epoch  99 Step 21 Train CE 1.04007 Train Acc 0.63000
# Epoch  99 Step 22 Train CE 0.87620 Train Acc 0.68000
# Epoch  99 Step 23 Train CE 1.03662 Train Acc 0.63000
# Epoch  99 Step 24 Train CE 1.06686 Train Acc 0.60000
# Epoch  99 Step 25 Train CE 0.91941 Train Acc 0.70000
# Epoch  99 Step 26 Train CE 1.09763 Train Acc 0.59000
# Epoch  99 Step 27 Train CE 0.88059 Train Acc 0.67000
# Epoch  99 Step 28 Train CE 1.30815 Train Acc 0.55000
# Epoch  99 Step 29 Train CE 0.97554 Train Acc 0.66000
# Epoch  99 Step 30 Train CE 0.89599 Train Acc 0.68000
# Epoch  99 Step 31 Train CE 0.91625 Train Acc 0.72000
# Epoch  99 Step 32 Train CE 0.84356 Train Acc 0.66000
# Epoch  99 Step 33 Train CE 0.77899 Train Acc 0.71622
# Epoch  99 Validation CE 0.97767 Validation Acc 0.63246
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-6abe7a038e29> in <module>()
#       1 print(eps)
#       2 #Train model.
# ----> 3 stats = Train(model, NNForward, NNBackward, NNUpdate, hyperparameters)
#       4
#       5 # Uncomment if you wish to save the model.
#
# <ipython-input-69-a8f8232a1b5e> in Train(model, forward, backward, update, hypers, verbose)
#      72         valid_ce_list.append((epoch, valid_ce))
#      73         valid_acc_list.append((epoch, valid_acc))
# ---> 74         DisplayPlot(train_ce_list, valid_ce_list, 'Cross Entropy', number=0)
#      75         DisplayPlot(train_acc_list, valid_acc_list, 'Accuracy', number=1)
#      76
#
# /home/lichiheng/Documents/CSC311/hw2/q3_materials/util.pyc in DisplayPlot(train, valid, ylabel, number)
#      65     train = np.array(train)
#      66     valid = np.array(valid)
# ---> 67     plt.plot(train[:, 0], train[:, 1], 'b', label='Train')
#      68     plt.plot(valid[:, 0], valid[:, 1], 'g', label='Validation')
#      69     plt.xlabel('Epoch')
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3350 @_autogen_docstring(Axes.plot)
#    3351 def plot(*args, **kwargs):
# -> 3352     ax = gca()
#    3353     # Deprecated: allow callers to override the hold state
#    3354     # by passing hold=True|False
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/pyplot.pyc in gca(**kwargs)
#     967     matplotlib.figure.Figure.gca : The figure's gca method.
#     968     """
# --> 969     return gcf().gca(**kwargs)
#     970
#     971 # More ways of creating axes:
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/figure.pyc in gca(self, **kwargs)
#    1842
#    1843         # no axes found, so create one which spans the figure
# -> 1844         return self.add_subplot(1, 1, 1, **kwargs)
#    1845
#    1846     def sca(self, a):
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1255                     self._axstack.remove(ax)
#    1256
# -> 1257             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1258         self._axstack.add(key, a)
#    1259         self.sca(a)
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      75
#      76         # _axes_class is set in the subplot_class_factory
# ---> 77         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      78         # add a layout box to this, for both the full axis, and the poss
#      79         # of the axis.  We need both because the axes may become smaller
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     509
#     510         # this call may differ for non-sep axes, e.g., polar
# --> 511         self._init_axis()
#     512         if facecolor is None:
#     513             facecolor = rcParams['axes.facecolor']
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _init_axis(self)
#     621         self.spines['top'].register_axis(self.xaxis)
#     622         self.yaxis = maxis.YAxis(self)
# --> 623         self.spines['left'].register_axis(self.yaxis)
#     624         self.spines['right'].register_axis(self.yaxis)
#     625         self._update_transScale()
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/spines.pyc in register_axis(self, axis)
#     171         self.axis = axis
#     172         if self.axis is not None:
# --> 173             self.axis.cla()
#     174         self.stale = True
#     175
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/axis.pyc in cla(self)
#     804         self.label.set_text('')  # self.set_label_text would change isDefault_
#     805
# --> 806         self._set_scale('linear')
#     807
#     808         # Clear the callback registry for this axis, or it may "leak"
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/axis.pyc in _set_scale(self, value, **kwargs)
#     770     def _set_scale(self, value, **kwargs):
#     771         self._scale = mscale.scale_factory(value, self, **kwargs)
# --> 772         self._scale.set_default_locators_and_formatters(self)
#     773
#     774         self.isDefault_majloc = True
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/scale.pyc in set_default_locators_and_formatters(self, axis)
#      71         linear scaling.
#      72         """
# ---> 73         axis.set_major_locator(AutoLocator())
#      74         axis.set_major_formatter(ScalarFormatter())
#      75         axis.set_minor_formatter(NullFormatter())
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/ticker.pyc in __init__(self)
#    2502             nbins = 'auto'
#    2503             steps = [1, 2, 2.5, 5, 10]
# -> 2504         MaxNLocator.__init__(self, nbins=nbins, steps=steps)
#    2505
#    2506
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/ticker.pyc in __init__(self, *args, **kwargs)
#    1847                 raise ValueError(
#    1848                     "Keywords are required for all arguments except 'nbins'")
# -> 1849         self.set_params(**self.default_params)
#    1850         self.set_params(**kwargs)
#    1851
#
# /home/lichiheng/.conda/envs/py27/lib/python2.7/site-packages/matplotlib/ticker.pyc in set_params(self, **kwargs)
#    1884                 self._nbins = int(self._nbins)
#    1885         if 'symmetric' in kwargs:
# -> 1886             self._symmetric = kwargs['symmetric']
#    1887         if 'prune' in kwargs:
#    1888             prune = kwargs['prune']
#
# KeyboardInterrupt:

# %% [markdown]
# **Comment on the stats:** The perfomance in terms of accuarcy of validation set is less than the trainning set.

# %%
#### Plot of cross entropy
![title](Figure_0.png)

#### Plot of accuracy
![title](Figure_1.png)

# %% [markdown]
# ## Q3.2

# %%
import matplotlib.pyplot as plt

# %%
def train_with_hyper_list(hypers, parameters, name):
    # Input-output dimensions.
    num_inputs = 2304
    num_outputs = 7

    hyper_clone = dict(hypers)
    
    train_ce = []
    train_acc = []
    valid_ce = []
    valid_acc = []

    for param in parameters:

        # Reinitialize model.
        model = InitNN(num_inputs, hypers["num_hiddens"], num_outputs)
        # Check gradient implementation.
        print('Checking gradients...')
        x = np.random.rand(10, 48 * 48) * 0.1
        CheckGrad(model, NNForward, NNBackward, 'W3', x)
        CheckGrad(model, NNForward, NNBackward, 'b3', x)
        CheckGrad(model, NNForward, NNBackward, 'W2', x)
        CheckGrad(model, NNForward, NNBackward, 'b2', x)
        CheckGrad(model, NNForward, NNBackward, 'W1', x)
        CheckGrad(model, NNForward, NNBackward, 'b1', x)
        print('Gradient check passed...')
        print('Starting trainning...')
        print()
        print(name + " = " + str(param) + ":")
        print()
        hyper_clone[name] = param
        # Train model.
        stats = Train(model, NNForward, NNBackward, NNUpdate, hyper_clone, verbose=False, diagram=False)
        # Only concern the ce of the last iteration
        train_ce.append(stats[1]["train_ce"][-1][1])
        train_acc.append(stats[1]["train_acc"][-1][1])
        valid_ce.append(stats[1]["valid_ce"][-1][1])
        valid_acc.append(stats[1]["valid_acc"][-1][1])
        print()
    # %matplotlib inline
    plt.figure(figsize=(20, 5))
    plt.subplot(121)
    plt.plot(parameters, train_ce, '-o', label="training set")
    plt.plot(parameters, valid_ce, '-o', label="validation set")
    plt.xlabel(name)
    plt.ylabel("cross entrophy loss")
    plt.legend()

    plt.subplot(122)
    plt.plot(parameters, train_acc, '-o', label="training set")
    plt.plot(parameters, valid_acc, '-o', label="validation set")
    plt.xlabel(name)
    plt.ylabel("accuracy")
    plt.legend()
    
    # Report the best hyperparameter setting
    argmin = np.argmin(valid_ce)
    best = parameters[argmin]
    print(name + " choosen: " + str(best))
    
    return best

# %% [markdown]
# #### Train with different learning rates

# %%
learning_rates = [0.001, 0.1, 0.2, 0.5, 1.0]

# %%
best_eps = train_with_hyper_list(hyperparameters, learning_rates, "eps")
# Out:
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# eps = 0.001:
#
# CE: Train 1.10412 Validation 1.12326 Test 1.15264
# Acc: Train 0.60729 Validation 0.57995 Test 0.57662
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# eps = 0.1:
#
# CE: Train 0.53448 Validation 1.01282 Test 0.96629
# Acc: Train 0.80794 Validation 0.69690 Test 0.68312
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# eps = 0.2:
#
# CE: Train 2.45219 Validation 2.53740 Test 2.33438
# Acc: Train 0.33817 Validation 0.32936 Test 0.37143
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# eps = 0.5:
#
# CE: Train 1.86108 Validation 1.85905 Test 1.83904
# Acc: Train 0.28542 Validation 0.27924 Test 0.31688
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# eps = 1.0:
#
# CE: Train 1.86245 Validation 1.86104 Test 1.84036
# Acc: Train 0.28542 Validation 0.27924 Test 0.31688
#
# eps choosen: 0.1

# %% [markdown]
# ### Comment
#
# As the learning rate increase, within 0.1, the larger the learning rate, the cross entropy was more convergent. However, as the learning rate get bigger 0.1, the cross entropy didn't converge as the learning rate increase. It is due to the fact that, the cross entrophy keep escaping from the global minimum.

# %%
hyperparameters["eps"] = best_eps

# %% [markdown]
# #### Given the choosen best learning rate, try different momentum.

# %%
momentums = [0.0, 0.45, 0.9]

# %%
best_momentum = train_with_hyper_list(hyperparameters, momentums, "momentum")
# Out:
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# momentum = 0.0:
#
# CE: Train 0.38254 Validation 1.00641 Test 0.91246
# Acc: Train 0.86663 Validation 0.73031 Test 0.71169
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# momentum = 0.45:
#
# CE: Train 0.53448 Validation 1.01282 Test 0.96629
# Acc: Train 0.80794 Validation 0.69690 Test 0.68312
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# momentum = 0.9:
#
# CE: Train 0.30314 Validation 2.07246 Test 2.10522
# Acc: Train 0.89923 Validation 0.71599 Test 0.66234
#
# momentum choosen: 0.0

# %% [markdown]
# ### Comment

# %%
hyperparameters["momentum"] = best_momentum

# %% [markdown]
# #### Given the choosen best momentum and learning rate, try different mini-batch sizes.

# %%
batches = [200, 500, 800, 900, 1000]

# %%
best_batch_size = train_with_hyper_list(hyperparameters, batches, "batch_size")
# Out:
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# batch_size = 200:
#
# CE: Train 0.66596 Validation 0.97049 Test 0.88406
# Acc: Train 0.76378 Validation 0.68019 Test 0.68831
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# batch_size = 500:
#
# CE: Train 1.00303 Validation 1.08501 Test 1.08839
# Acc: Train 0.63367 Validation 0.62053 Test 0.59221
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# batch_size = 800:
#
# CE: Train 1.29053 Validation 1.29646 Test 1.32629
# Acc: Train 0.52786 Validation 0.54415 Test 0.52727
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# batch_size = 900:
#
# CE: Train 1.01786 Validation 1.07067 Test 1.03939
# Acc: Train 0.62596 Validation 0.63246 Test 0.60260
#
# Checking gradients...
# Gradient check passed...
# Starting trainning...
#
# batch_size = 1000:
#
# CE: Train 0.98664 Validation 1.04708 Test 1.07973
# Acc: Train 0.63041 Validation 0.63007 Test 0.62857
#
# batch_size choosen: 200

# %% [markdown]
# ### Comment
# The cross entrophy losses of both training and test set first increase until the batch size reach 800. After 800, the cross entrophy losses start to decrease. However, the accuracy of predicting the label on the validation set is never as high as the when the batch size is 200. It is obvious that, when the batch is 200, the difference of the cross entrophy losses between the validation set and the training set is the greatest. It indicates that the smaller batch size helps to reduce overfit of the model.

# %%
hyperparameters["batch_size"] = best_batch_size

# %% [markdown]
# #### When tuning the eps, momentum, and batch size of the network, I first tried different values of learning rate and select the one which yeilded the lowest cross validation error, then fixed the momentum and batch size one by one by fixing the others and trying different values and select the one yielded the lowest cross validation error.

# %% [markdown]
# #### Try 3 different values fo the number of hiddent units

# %%
# Fix momentum
hyperparameters["momentum"] = 0.9
# Change learning rate and number of epochs
hyperparameters["eps"] = 0.1
hyperparameters["num_epochs"] = 220
epochs = [220, 300, 600]

hidden_units = [[10, 20], [30, 60], [50, 100]]
for hidden_unit in hidden_units:
    
    # Reinitialize model.
    model = InitNN(num_inputs, hidden_unit, num_outputs)

    # Uncomment to reload trained model here.
    # model = Load(model_fname)

    # Check gradient implementation.
    print('Checking gradients...')
    x = np.random.rand(10, 48 * 48) * 0.1
    CheckGrad(model, NNForward, NNBackward, 'W3', x)
    CheckGrad(model, NNForward, NNBackward, 'b3', x)
    CheckGrad(model, NNForward, NNBackward, 'W2', x)
    CheckGrad(model, NNForward, NNBackward, 'b2', x)
    CheckGrad(model, NNForward, NNBackward, 'W1', x)
    CheckGrad(model, NNForward, NNBackward, 'b1', x)
    print('Gradient check passed...')
    print('Starting trainning...')
    print("hiddent_unit" + " = " + str(hidden_unit) + ":")

    # Train model.
    stats = Train(model, NNForward, NNBackward, NNUpdate, hyperparameters, verbose=False)
# Out:
# Checking gradients...
# Gradient check passed...
# Starting trainning...
# hiddent_unit = [10, 20]:
# CE: Train 0.46053 Validation 0.94664 Test 0.80102
# Acc: Train 0.83432 Validation 0.72315 Test 0.73506
# Checking gradients...
# Gradient check passed...
# Starting trainning...
# hiddent_unit = [30, 60]:
